# %%
# Import the required classes
from pyspark import SparkConf
import pandas as pd
from pyspark.sql.functions import col
from pyspark.sql import functions as F
from pyspark.rdd import RDD
from pyspark.sql.types import IntegerType
import numpy as np

# %% [markdown]
# # Part A : Working with RDDs and DataFrames (80%)
# ## 1. Working with RDD (25%)
# ### 1.1 Data Preparation and Loading (5%)

# %%
# 1.
# Set working processors to number of logical ocres on the machine
master = "local[*]"
# Name to be shown on Spark cluster UI page
app_name = "Assignment 1: Analyzing Road Crash Data"

# setting configuration parameters for Spark
spark_conf = SparkConf().setMaster(master).setAppName(app_name)

# Import SparkContext and SparkSession classes 
from pyspark import SparkContext
from pyspark.sql import SparkSession

# Building SparkSession
spark = SparkSession.builder.config(conf=spark_conf).getOrCreate()
sc = spark.sparkContext
sc.setLogLevel('ERROR')

# %%
# 2.
# Read all files ending in Units.csv
rdd_units = sc.textFile("*Units.csv")

# %%
# 3.
# Read all files ending in Crash.csv
rdd_crashes = sc.textFile("*Crash.csv")

# %%
#4.
# Storing first row 
header = rdd_units.first()
# Removing the first row
rdd_units = rdd_units.filter(lambda x: x != header)
# Number of rows
rdd_units.count()
# Out:
# 153854

# %%
# 4.
# Displaying the first 10 records
rdd_units.take(10)
# Out:
# ['"2016-1-15/08/2019","01",0,"SA","OMNIBUS","2011","North","Male","056","SA","HR","Full","Not Towing","Straight Ahead","010","5121",,',
#  '"2016-1-15/08/2019","02",1,,"Pedestrian on Road",,"East","Male","072",,,,,"Walking on Road",,"5084",,',
#  '"2016-2-15/08/2019","01",0,"SA","Motor Cars - Sedan","2004","Unknown","Female","023","SA","C ","Full","Not Towing","Straight Ahead","001","5087",,',
#  '"2016-2-15/08/2019","02",0,"SA","Station Wagon","2008","Unknown","Male","040","SA","C ","Full","Not Towing","Straight Ahead","001","5084",,',
#  '"2016-3-15/08/2019","01",0,"SA","RIGID TRUCK LGE GE 4.5T","1990","South","Unknown","XXX","SA","MR","Provisional 2","Not Towing","Straight Ahead","001","5115",,',
#  '"2016-3-15/08/2019","02",0,"SA","Panel Van","2013","South","Male","023","SA","C ","Full","Not Towing","Straight Ahead","001","5110",,',
#  '"2016-4-15/08/2019","01",0,"SA","Station Wagon","2002","East","Female","033","SA","C ","Full","Not Towing","Straight Ahead","001","5169",,',
#  '"2016-4-15/08/2019","02",0,"UNKNOWN","Other Defined Special Vehicle","XXXX","North","Unknown","XXX","UNKNOWN","XX","Unknown","Unknown","Reversing","001","XXXX",,',
#  '"2016-5-15/08/2019","01",1,"SA","Motor Cars - Sedan","1997","South East","Male","042","SA","C ","Full","Not Towing","Right Turn","001","XXXX",,',
#  '"2016-5-15/08/2019","02",2,"SA","Utility","2015","North East","Male","059","SA","MC","Full","Not Towing","Straight Ahead","002","5114",,']

# %%
#4.
# Storing first row 
header = rdd_crashes.first()
# Removing the first row
rdd_crashes = rdd_crashes.filter(lambda x: x != header)
# Number of rows
rdd_crashes.count()
# Out:
# 72006

# %%
# 4.
# Displaying the first 10 records
rdd_crashes.take(10)
# Out:
# ['"2019-1-8/07/2020","2 Metropolitan","HAMPSTEAD GARDENS","5086","CITY OF PORT ADELAIDE ENFIELD",2,0,0,0,0,2019,"June","Wednesday","11:15 am","060","Cross Road","Straight road","Level","Not Applicable","Sealed","Dry","Not Raining","Daylight","Right Angle","01","Driver Rider","1: PDO","Give Way Sign","","",1331810.03,1676603.26,"13318101676603"',
#  '"2019-2-8/07/2020","2 Metropolitan","DRY CREEK","5094","CITY OF SALISBURY",2,0,0,0,0,2019,"January","Tuesday","12:49 am","090","Divided Road","Straight road","Level","Not Applicable","Sealed","Dry","Not Raining","Night","Rear End","02","Driver Rider","1: PDO","No Control","","",1328376.2,1682942.63,"13283761682943"',
#  '"2019-3-8/07/2020","2 Metropolitan","MILE END","5031","CITY OF WEST TORRENS",2,1,0,0,1,2019,"January","Tuesday","12:00 am","060","Divided Road","Straight road","Level","Not Applicable","Sealed","Dry","Not Raining","Night","Hit Pedestrian","01","Driver Rider","2: MI","No Control","","",1325819.68,1670994.26,"13258201670994"',
#  '"2019-4-8/07/2020","2 Metropolitan","PARALOWIE","5108","CITY OF SALISBURY",2,1,0,1,0,2019,"January","Tuesday","12:05 am","050","Not Divided","CURVED, VIEW OPEN","Level","Not Applicable","Sealed","Dry","Not Raining","Night","Hit Fixed Object","01","Driver Rider","3: SI","No Control","","",1328320.6,1690237.08,"13283211690237"',
#  '"2019-5-8/07/2020","2 Metropolitan","MOUNT BARKER","5251","DC MT.BARKER.                 ",2,0,0,0,0,2019,"January","Tuesday","05:15 am","110","Divided Road","Straight road","Slope","Not Applicable","Sealed","Dry","Not Raining","Night","Hit Animal","02","Animal","1: PDO","No Control","","",1353279.99,1655645.15,"13532801655645"',
#  '"2019-6-8/07/2020","2 Metropolitan","TORRENSVILLE","5031","CITY OF WEST TORRENS",2,1,0,0,1,2019,"January","Tuesday","07:00 am","050","Divided Road","Straight road","Level","Not Applicable","Sealed","Dry","Not Raining","Daylight","Hit Fixed Object","01","Driver Rider","2: MI","No Control","","",1324652.75,1672027.64,"13246531672028"',
#  '"2019-7-8/07/2020","2 Metropolitan","BEDFORD PARK","5042","CC MITCHAM.                   ",2,3,0,0,3,2019,"January","Tuesday","09:40 am","050","Cross Road","Straight road","Level","Not Applicable","Sealed","Dry","Not Raining","Daylight","Right Angle","02","Driver Rider","2: MI","Traffic Signals","","",1325156.2,1660414.38,"13251561660414"',
#  '"2019-8-8/07/2020","3 Country","WYE","5291","DISTRICT COUNCIL OF GRANT",1,1,0,0,1,2019,"January","Tuesday","12:15 pm","110","Not Divided","CURVED, VIEW OPEN","Level","Not Applicable","Sealed","Dry","Not Raining","Daylight","Roll Over","01","Driver Rider","2: MI","No Control","","",1517347.8,1321979.33,"15173481321979"',
#  '"2019-9-8/07/2020","3 Country","MOUNT GAMBIER","5290","CC MT.GAMBIER.                ",1,1,0,0,1,2019,"January","Tuesday","11:45 am","050","T-Junction","Straight road","Bottom of Hill","Not Applicable","Sealed","Dry","Not Raining","Daylight","Roll Over","01","Driver Rider","2: MI","Stop Sign","","",1510220.05,1340472.35,"15102201340472"',
#  '"2019-10-8/07/2020","3 Country","OVERLAND CORNER","5330","THE BERRI BARMERA COUNCIL",1,1,0,1,0,2019,"January","Tuesday","12:30 pm","080","Not Divided","CURVED, VIEW OPEN","Slope","Not Applicable","Sealed","Dry","Not Raining","Daylight","Roll Over","01","Driver Rider","3: SI","No Control","","",1492599.9,1749395.71,"14926001749396"']

# %% [markdown]
# ### 1.2 Data Partitioning in RDD (10%)

# %%
# 1.
# Default number of partitions for rdd_units
print("Number of partitions in rdd units:", rdd_units.getNumPartitions())
# Default number of partitions for rdd_crashes
print("Number of partitions in rdd crashes :", rdd_crashes.getNumPartitions())
# Out:
# Number of partitions in rdd units: 5
# Number of partitions in rdd crashes : 5

# %%
# 2.a.
# Storing first row 
header = rdd_units.first()
# Removing the first row
rdd_units = rdd_units.filter(lambda x: x != header)
# Splitting different columns
rdd_units_1 = rdd_units.map(lambda x: x.split(","))
# Making Lic State as key and other columns as Value
rdd_units_2 = rdd_units_1.map(lambda x: (x.pop(9), x[:]))

# %%
# 2.b.
# Function to implement hash partitioning
def hash_function(key):
    if key == '"SA"':
        partition = 0
    else:
        partition = 1
    return partition

# %%
# 2.b.
# hash partitioning
rdd_hash = rdd_units_2.partitionBy(2, hash_function)

# %%
# 2.c.
# A Function to print number of records in each partition
def print_partitions(data):
    
    numPartitions = data.getNumPartitions()
    partitions = data.glom().collect()
    
    print(f"NUMBER OF PARTITIONS: {numPartitions}")
    for index, partition in enumerate(partitions):
        # show partition if it is not empty
        if len(partition) > 0:
            print(f"Partition {index}: {len(partition)} records")

# %%
# 2.c.
print_partitions(rdd_hash)
# Out:
# NUMBER OF PARTITIONS: 2
# Partition 0: 109684 records
# Partition 1: 44170 records

# %% [markdown]
# We observe that the number of records in partition 0 are nearly 2.5 times the number of records in partition 1. Therefore, the data is definitely skewed and we can say that there are a huge number of vehicles registered in SA state.

# %% [markdown]
# ### 1.3 Query/Analysis (10%)

# %%
# 1.
# Extracting columns sex and age and removing quotes
agesex_rdd = rdd_units_1.map(lambda x: (x[7].strip('""'), x[8].strip('""')))
agesex_rdd.take(10)
# Out:
# [('Male', '056'),
#  ('Male', '072'),
#  ('Female', '023'),
#  ('Male', '040'),
#  ('Unknown', 'XXX'),
#  ('Male', '023'),
#  ('Female', '033'),
#  ('Unknown', 'XXX'),
#  ('Male', '042'),
#  ('Male', '059')]

# %%
# 1.
# Filtering males and females
male = agesex_rdd.filter(lambda x: x[0]=='Male' and x[1]!='XXX')
female = agesex_rdd.filter(lambda x: x[0]=='Female' and x[1]!= 'XXX')

# %%
# 1.
# Type Casting string to integer
male_age = male.map(lambda x: int(x[1]))
# Average male age
male_age.mean()
# Out:
# 40.97596029992008

# %%
# 1.
# Type Casting string to integer
female_age = female.map(lambda x: int(x[1]))
# Average female age
female_age.mean()
# Out:
# 40.38729268862415

# %%
# 2.
# Extracting columns Veh Reg State, Unit Type, Veh Year and removing quotes
rdd_veh = rdd_units_1.map(lambda x: (x[3].strip('""'), x[4].strip('""'), x[5].strip('""')))

# %%
# 2.
# Removing veh year having null and xxxx values
rdd_veh = rdd_veh.filter(lambda x: x[2]!='XXXX' and x[2]!='')

# %%
# 2.
# Type Casting string to integer
rdd_veh = rdd_veh.map(lambda x: (x[0], x[1], int(x[2])))
rdd_veh.take(5)
# Out:
# [('SA', 'OMNIBUS', 2011),
#  ('SA', 'Motor Cars - Sedan', 2004),
#  ('SA', 'Station Wagon', 2008),
#  ('SA', 'RIGID TRUCK LGE GE 4.5T', 1990),
#  ('SA', 'Panel Van', 2013)]

# %%
# 2.
# Get max by value in index 2 (veh year)
veh_max = rdd_veh.max(key=lambda x: x[2]) 
# Newest vehicle
print(veh_max)
# Out:
# ('SA', 'Station Wagon', 2019)

# %%
# 2.
# Get min by value in index 2 (veh year)
veh_min = rdd_veh.min(key=lambda x: x[2]) 
# Oldest vehicle
print(veh_min)
# Out:
# ('VIC', 'Motor Cycle', 1900)

# %% [markdown]
# ## 2. Working with DataFrames (35%)
# ###  2.1 Data Preparation and Loading (5%)

# %%
# 1.
# Loading all files ending with Units.csv into a single df
df_units = spark.read.csv("*Units.csv", header="true")
# Loading all files ending with Crash.csv into a single df
df_crashes = spark.read.csv("*Crash.csv", header="true")

# %%
# 2.
# Displaying schema for units df
df_units.printSchema()
# Out:
# root
#  |-- REPORT_ID: string (nullable = true)
#  |-- Unit No: string (nullable = true)
#  |-- No Of Cas: string (nullable = true)
#  |-- Veh Reg State: string (nullable = true)
#  |-- Unit Type: string (nullable = true)
#  |-- Veh Year: string (nullable = true)
#  |-- Direction Of Travel: string (nullable = true)
#  |-- Sex: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Lic State: string (nullable = true)
#  |-- Licence Class: string (nullable = true)
#  |-- Licence Type: string (nullable = true)
#  |-- Towing: string (nullable = true)
#  |-- Unit Movement: string (nullable = true)
#  |-- Number Occupants: string (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Rollover: string (nullable = true)
#  |-- Fire: string (nullable = true)

# %%
# 2.
# Displaying schema for crashes df
df_crashes.printSchema()
# Out:
# root
#  |-- REPORT_ID: string (nullable = true)
#  |-- Stats Area: string (nullable = true)
#  |-- Suburb: string (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- LGA Name: string (nullable = true)
#  |-- Total Units: string (nullable = true)
#  |-- Total Cas: string (nullable = true)
#  |-- Total Fats: string (nullable = true)
#  |-- Total SI: string (nullable = true)
#  |-- Total MI: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- Time: string (nullable = true)
#  |-- Area Speed: string (nullable = true)
#  |-- Position Type: string (nullable = true)
#  |-- Horizontal Align: string (nullable = true)
#  |-- Vertical Align: string (nullable = true)
#  |-- Other Feat: string (nullable = true)
#  |-- Road Surface: string (nullable = true)
#  |-- Moisture Cond: string (nullable = true)
#  |-- Weather Cond: string (nullable = true)
#  |-- DayNight: string (nullable = true)
#  |-- Crash Type: string (nullable = true)
#  |-- Unit Resp: string (nullable = true)
#  |-- Entity Code: string (nullable = true)
#  |-- CSEF Severity: string (nullable = true)
#  |-- Traffic Ctrls: string (nullable = true)
#  |-- DUI Involved: string (nullable = true)
#  |-- Drugs Involved: string (nullable = true)
#  |-- ACCLOC_X: string (nullable = true)
#  |-- ACCLOC_Y: string (nullable = true)
#  |-- UNIQUE_LOC: string (nullable = true)

# %% [markdown]
# ### 2.2 Query/Analysis (15%)

# %%
# 1.
# using cast function to change the datatype of Total Cas column
df_crashes = df_crashes.withColumn('Total Cas', F.col('Total Cas').cast(IntegerType()))
# display the datatype of all columns
display(df_crashes)
# Out:
# DataFrame[REPORT_ID: string, Stats Area: string, Suburb: string, Postcode: string, LGA Name: string, Total Units: string, Total Cas: int, Total Fats: string, Total SI: string, Total MI: string, Year: string, Month: string, Day: string, Time: string, Area Speed: string, Position Type: string, Horizontal Align: string, Vertical Align: string, Other Feat: string, Road Surface: string, Moisture Cond: string, Weather Cond: string, DayNight: string, Crash Type: string, Unit Resp: string, Entity Code: string, CSEF Severity: string, Traffic Ctrls: string, DUI Involved: string, Drugs Involved: string, ACCLOC_X: string, ACCLOC_Y: string, UNIQUE_LOC: string]

# %%
# 1.
# filtering adelaide suburbs where Total cas is greater than 3
df_adelaide = df_crashes.filter(df_crashes['Suburb'] == 'ADELAIDE').filter(df_crashes['Total Cas']>3)
print("Incidents:", df_adelaide.count())
df_adelaide.show()
# Out:
# Incidents: 4
# +--------------------+----------+--------+--------+----------------+-----------+---------+----------+--------+--------+----+--------+--------+--------+----------+-------------+----------------+--------------+--------------------+------------+-------------+------------+--------+--------------+---------+------------+-------------+---------------+------------+--------------+----------+----------+--------------+
# |           REPORT_ID|Stats Area|  Suburb|Postcode|        LGA Name|Total Units|Total Cas|Total Fats|Total SI|Total MI|Year|   Month|     Day|    Time|Area Speed|Position Type|Horizontal Align|Vertical Align|          Other Feat|Road Surface|Moisture Cond|Weather Cond|DayNight|    Crash Type|Unit Resp| Entity Code|CSEF Severity|  Traffic Ctrls|DUI Involved|Drugs Involved|  ACCLOC_X|  ACCLOC_Y|    UNIQUE_LOC|
# +--------------------+----------+--------+--------+----------------+-----------+---------+----------+--------+--------+----+--------+--------+--------+----------+-------------+----------------+--------------+--------------------+------------+-------------+------------+--------+--------------+---------+------------+-------------+---------------+------------+--------------+----------+----------+--------------+
# | 2018-601-17/01/2020|    1 City|ADELAIDE|    5000|CITY OF ADELAIDE|          8|        4|         0|       2|       2|2018| January|  Sunday|09:12 pm|       050|  Not Divided|   Straight road|         Level|      Not Applicable|      Sealed|          Dry| Not Raining|   Night|Hit Pedestrian|       01|Driver Rider|        3: SI|     No Control|        null|          null|1329806.36|1670224.76|13298061670225|
# |2017-1613-15/08/2019|    1 City|ADELAIDE|    5000|CITY OF ADELAIDE|          2|        4|         0|       0|       4|2017|February|Saturday|04:00 pm|       050|   Cross Road|   Straight road|         Level|      Not Applicable|      Sealed|          Dry| Not Raining|Daylight|    Right Turn|       01|Driver Rider|        2: MI|Traffic Signals|        null|          null|1327951.24|1669556.92|13279511669557|
# |2017-12182-15/08/...|    1 City|ADELAIDE|    5000|CITY OF ADELAIDE|          6|        5|         0|       1|       4|2017|December|Saturday|04:08 pm|       050|   Cross Road|   Straight road|         Level|      Not Applicable|      Sealed|          Wet| Not Raining|Daylight|Hit Pedestrian|       01|Driver Rider|        3: SI|Traffic Signals|        null|          null| 1329016.2|1670995.07|13290161670995|
# |2019-10404-8/07/2020|    1 City|ADELAIDE|    5000|CITY OF ADELAIDE|          4|        6|         0|       0|       6|2019| October|  Monday|08:20 am|       060| Divided Road|   Straight road|         Level|Driveway or Entrance|      Sealed|          Dry| Not Raining|Daylight|    Right Turn|       01|Driver Rider|        2: MI|     No Control|        null|          null|1327088.72|1670880.07|13270891670880|
# +--------------------+----------+--------+--------+----------------+-----------+---------+----------+--------+--------+----+--------+--------+--------+----------+-------------+----------------+--------------+--------------------+------------+-------------+------------+--------+--------------+---------+------------+-------------+---------------+------------+--------------+----------+----------+--------------+

# %%
# 2.
# Displaying 10 events with highest casualities
df_crashes.sort("Total Cas", ascending=False).show(10)
# Out:
# +--------------------+--------------+---------------+--------+--------------------+-----------+---------+----------+--------+--------+----+--------+---------+--------+----------+-------------+--------------------+--------------+--------------+------------+-------------+------------+--------+-----------+---------+------------+-------------+---------------+------------+--------------+----------+----------+--------------+
# |           REPORT_ID|    Stats Area|         Suburb|Postcode|            LGA Name|Total Units|Total Cas|Total Fats|Total SI|Total MI|Year|   Month|      Day|    Time|Area Speed|Position Type|    Horizontal Align|Vertical Align|    Other Feat|Road Surface|Moisture Cond|Weather Cond|DayNight| Crash Type|Unit Resp| Entity Code|CSEF Severity|  Traffic Ctrls|DUI Involved|Drugs Involved|  ACCLOC_X|  ACCLOC_Y|    UNIQUE_LOC|
# +--------------------+--------------+---------------+--------+--------------------+-----------+---------+----------+--------+--------+----+--------+---------+--------+----------+-------------+--------------------+--------------+--------------+------------+-------------+------------+--------+-----------+---------+------------+-------------+---------------+------------+--------------+----------+----------+--------------+
# | 2017-288-15/08/2019|2 Metropolitan|     PARA HILLS|    5096|   CITY OF SALISBURY|          2|       11|         0|       1|      10|2017| January|Wednesday|01:13 pm|       060|   T-Junction|       Straight road| Crest of Hill|Not Applicable|      Sealed|          Dry| Not Raining|Daylight|Right Angle|       01|Driver Rider|        3: SI|      Stop Sign|        null|          null| 1334428.9|1683032.96|13344291683033|
# |2016-3035-15/08/2019|2 Metropolitan|        HACKHAM|    5163| CITY OF ONKAPARINGA|          3|        9|         3|       5|       1|2016| January| Saturday|11:50 am|       080|   T-Junction|       Straight road|         Level|Not Applicable|      Sealed|          Dry| Not Raining|Daylight| Right Turn|       01|Driver Rider|     4: Fatal|     No Control|        null|          null|1320361.49|1645195.63|13203611645196|
# |2016-6630-15/08/2019|2 Metropolitan|  KANGAROO FLAT|    5118|LIGHT REGIONAL CO...|          3|        9|         0|       2|       7|2016|   April|Wednesday|09:00 pm|       100|  Not Divided|CURVED, VIEW OBSC...|         Level|Not Applicable|      Sealed|          Dry| Not Raining|   Night|    Head On|       01|Driver Rider|        3: SI|     No Control|        null|          null|1339316.32|1710314.92|13393161710315|
# |2019-11734-8/07/2020|2 Metropolitan|          STURT|    5047|CC MARION.       ...|          2|        9|         0|       1|       8|2019|November|   Sunday|07:25 pm|       060|   T-Junction|       Straight road|         Level|Not Applicable|      Sealed|          Dry| Not Raining|Daylight| Right Turn|       02|Driver Rider|        3: SI|Traffic Signals|        null|          null|1324428.84|1659884.95|13244291659885|
# |2016-14407-15/08/...|     3 Country|      STOCKWELL|    5355|THE BAROSSA COUNCIL.|          2|        8|         1|       6|       1|2016| October|   Sunday|03:46 pm|       100|  Not Divided|       Straight road| Crest of Hill|Not Applicable|    Unsealed|          Dry| Not Raining|Daylight|    Head On|       01|Driver Rider|     4: Fatal|     No Control|        null|          null|1373964.45|1723462.57|13739641723463|
# |2016-7073-15/08/2019|     3 Country|       MERRITON|    5523|PT.PIRIE CITY & D...|          2|        8|         4|       3|       1|2016|   April|   Sunday|12:35 pm|       110|  Not Divided|       Straight road|         Level|Not Applicable|      Sealed|          Dry| Not Raining|Daylight|    Head On|       01|Driver Rider|     4: Fatal|     No Control|        null|          null|1293759.89|1840109.96|12937601840110|
# |2015-2823-21/08/2019|     3 Country|         HAWKER|    5434|THE FLINDERS RANG...|          1|        8|         0|       0|       8|2015|   March|   Monday|06:00 pm|       110|  Not Divided|       Straight road|         Level|Not Applicable|      Sealed|          Dry| Not Raining|Daylight|  Roll Over|       01|Driver Rider|        2: MI|     No Control|        null|          null|1315077.61|2022309.34|13150782022309|
# |2015-12591-21/08/...|     3 Country|        MALLALA|    5502|DC MALLALA.      ...|          2|        7|         0|       2|       5|2015| October|   Sunday|02:30 pm|       100|   Cross Road|       Straight road|         Level|Not Applicable|    Unsealed|          Dry| Not Raining|Daylight|Right Angle|       01|Driver Rider|        3: SI|  Give Way Sign|        null|          null|1325122.01|1724860.95|13251221724861|
# |2015-13713-21/08/...|2 Metropolitan|ELIZABETH GROVE|    5112|   CITY OF PLAYFORD.|          2|        7|         0|       0|       7|2015|November|   Friday|03:42 pm|       080|   T-Junction|       Straight road|         Level|Not Applicable|      Sealed|          Dry| Not Raining|Daylight|   Rear End|       01|Driver Rider|        2: MI|     No Control|        null|          null|1336118.68|1691385.65|13361191691386|
# |2015-6965-21/08/2019|     3 Country|       BEAUFORT|    5550|YORKE PENINSULA C...|          3|        7|         3|       4|       0|2015|    June|   Monday|11:13 am|       100|   T-Junction|       Straight road|         Level|Not Applicable|      Sealed|          Dry| Not Raining|Daylight|    Head On|       09|       Other|     4: Fatal|     No Control|        null|          null|1287930.19|1761652.36|12879301761652|
# +--------------------+--------------+---------------+--------+--------------------+-----------+---------+----------+--------+--------+----+--------+---------+--------+----------+-------------+--------------------+--------------+--------------+------------+-------------+------------+--------+-----------+---------+------------+-------------+---------------+------------+--------------+----------+----------+--------------+
# only showing top 10 rows

# %%
# 3.
# Total fatalities when grouped by Crash Type
df_crashes.groupBy("Crash Type")\
.agg(F.sum("Total Fats").alias("Total Fatalities"))\
.show()
# Out:
# +--------------------+----------------+
# |          Crash Type|Total Fatalities|
# +--------------------+----------------+
# |           Roll Over|            57.0|
# |  Hit Object on Road|             2.0|
# |      Hit Pedestrian|            70.0|
# |    Hit Fixed Object|           152.0|
# |               Other|             2.0|
# |          Side Swipe|            20.0|
# |             Head On|            86.0|
# |  Hit Parked Vehicle|             9.0|
# |          Right Turn|            18.0|
# |            Rear End|            16.0|
# |          Hit Animal|             4.0|
# |Left Road - Out o...|             1.0|
# |         Right Angle|            45.0|
# +--------------------+----------------+

# %%
# 4.
# Joining crash and units df on REPORT_ID
df_joint = df_units.join(df_crashes, df_crashes.REPORT_ID==df_units.REPORT_ID, how='outer')

# %%
# 4.
# Taking only unlicenced drivers 
df_unlicenced = df_joint.filter(df_joint['Licence Type']=='Unlicenced')

# %%
# 4.
# Total casualities for each suburb
df_unlicenced.groupBy("Suburb")\
.agg(F.sum("No Of Cas").alias("Total Casualities"))\
.sort("Total Casualities", ascending=False)\
.show()
# Out:
# +---------------+-----------------+
# |         Suburb|Total Casualities|
# +---------------+-----------------+
# |      DRY CREEK|             11.0|
# |       PROSPECT|             11.0|
# |        ENFIELD|             11.0|
# |      SALISBURY|             11.0|
# |   ANDREWS FARM|             10.0|
# | SALISBURY EAST|              8.0|
# | ELIZABETH PARK|              8.0|
# |SALISBURY DOWNS|              8.0|
# |       ADELAIDE|              8.0|
# |         BURTON|              8.0|
# | NORTH ADELAIDE|              7.0|
# |SALISBURY NORTH|              7.0|
# |  MOUNT GAMBIER|              7.0|
# |    COOBER PEDY|              7.0|
# |   BEDFORD PARK|              6.0|
# |ELIZABETH DOWNS|              6.0|
# |   DAVOREN PARK|              6.0|
# |  GILLES PLAINS|              6.0|
# |          BURRA|              6.0|
# |  MURRAY BRIDGE|              6.0|
# +---------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### 2.3 Severity Analysis (15%)

# %%
# 1.
# Total number of crashes for each severity level
df_crashes.groupBy("CSEF Severity").count().show()
# Out:
# +-------------+-----+
# |CSEF Severity|count|
# +-------------+-----+
# |     4: Fatal|  451|
# |        2: MI|21881|
# |       1: PDO|46696|
# |        3: SI| 2978|
# +-------------+-----+

# %% [markdown]
# Severity level 1:PDO (property damage only)is the most common.

# %%
# 2.a.
# Total number of cases involving drugs
total = df_crashes.filter(df_crashes['Drugs Involved']=='Y').count()

# Count and percentage for cases involving drugs
df_crashes.filter(df_crashes['Drugs Involved']=='Y')\
.groupBy("CSEF Severity")\
.count()\
.withColumn('Percentage', (F.col('count') / total) * 100)\
.show()
# Out:
# +-------------+-----+------------------+
# |CSEF Severity|count|        Percentage|
# +-------------+-----+------------------+
# |     4: Fatal|   82| 6.539074960127592|
# |        2: MI|  749|59.728867623604465|
# |       1: PDO|  176|14.035087719298245|
# |        3: SI|  247|19.696969696969695|
# +-------------+-----+------------------+

# %%
# 2.b.
# Total number of cases involving DUI/BAC
total = df_crashes.filter(df_crashes['DUI Involved']=='Y').count()

# Count and percentage for cases involving DUI/BAC
df_crashes.filter(df_crashes['DUI Involved']=='Y')\
.groupBy("CSEF Severity")\
.count()\
.withColumn('Percentage', (F.col('count') / total) * 100)\
.show()
# Out:
# +-------------+-----+------------------+
# |CSEF Severity|count|        Percentage|
# +-------------+-----+------------------+
# |     4: Fatal|   79|  3.51423487544484|
# |        2: MI|  737|  32.7846975088968|
# |       1: PDO| 1173|52.179715302491104|
# |        3: SI|  259| 11.52135231316726|
# +-------------+-----+------------------+

# %%
# 2.c
# Total number of cases involving DUI/BAC and drugs
total = df_crashes.filter(df_crashes['Drugs Involved']=='Y')\
        .filter(df_crashes['DUI Involved']=='Y').count()

# Count and percentage for cases involving DUI/BAC and drugs
df_crashes.filter(df_crashes['Drugs Involved']=='Y')\
.filter(df_crashes['DUI Involved']=='Y')\
.groupBy("CSEF Severity")\
.count()\
.withColumn('Percentage', (F.col('count') / total) * 100)\
.show()
# Out:
# +-------------+-----+------------------+
# |CSEF Severity|count|        Percentage|
# +-------------+-----+------------------+
# |     4: Fatal|   27|15.428571428571427|
# |        2: MI|   89|50.857142857142854|
# |       1: PDO|   24|13.714285714285715|
# |        3: SI|   35|              20.0|
# +-------------+-----+------------------+

# %%
# 2.d
# Total number of cases not involving DUI/BAC and drugs
total = df_crashes.filter(df_crashes['Drugs Involved'].isNull())\
        .filter((df_crashes['DUI Involved']).isNull()).count()

# Count and percentage for cases not involving DUI/BAC and drugs
df_crashes.filter(df_crashes['Drugs Involved'].isNull())\
.filter((df_crashes['DUI Involved']).isNull())\
.groupBy("CSEF Severity")\
.count()\
.withColumn('Percentage', (F.col('count') / total) * 100)\
.show()
# Out:
# +-------------+-----+------------------+
# |CSEF Severity|count|        Percentage|
# +-------------+-----+------------------+
# |     4: Fatal|  317| 0.461567582521586|
# |        2: MI|20484|29.825710916000524|
# |       1: PDO|45371| 66.06240626683557|
# |        3: SI| 2507|3.6503152346423215|
# +-------------+-----+------------------+

# %% [markdown]
# When no drugs are involved and the driver tested negative for an illegal level of BAC, the crashses that took place mostly resulted in a property damage only and very few of them were fatal. While, when both drugs were involved and driver tested postive for a high BAC level 50% of the cases resulted in a minor injury and 15% crashes were fatal, which is huge. When only drugs were involved 59% crashes resulted in a minor injury and when the driver tested positive for a high BAC level 52% cases resulted in only property damage and 32% cases resulted in a minor injury.
# We can also observer that highest number of cases were recorded when no drugs were involved and there was no detection of a high BAC level while there were only a few cases when both drugs and alcohol was involved.

# %% [markdown]
# ### 2.4 RDDs vs DataFrame vs Spark SQL (20%)

# %%
# register the original DataFrame as a temp view so that we can query it using SQL
df_units.createOrReplaceTempView("sql_units")
df_crashes.createOrReplaceTempView("sql_crashes")

# %%
# 1.
# Joining crash and units df on REPORT_ID
# Extracting columns date, time of crash and other required columns for suburb Adelaide

# %%
# %%time
df_joint = df_units.join(df_crashes, df_crashes.REPORT_ID==df_units.REPORT_ID, how='outer')
df_joint.filter(df_joint['Suburb']=='ADELAIDE')\
.select(F.concat('Year',F.lit("-"), 'Month' ,F.lit("-"), 'Day').alias("Date"), 'Time', 'Unit No', 'No Of Cas', 'Sex', 'Age', 'Licence Type')\
.show()
# Out:
# +--------------------+--------+-------+---------+-------+----+------------+
# |                Date|    Time|Unit No|No Of Cas|    Sex| Age|Licence Type|
# +--------------------+--------+-------+---------+-------+----+------------+
# |2016-November-Wed...|01:45 pm|     02|        1|   Male| 072|        null|
# |2016-November-Wed...|01:45 pm|     01|        0|   Male| 056|        Full|
# |2016-November-Tue...|03:40 pm|     02|        1| Female| 027|        null|
# |2016-November-Tue...|03:40 pm|     01|        0|   Male| 056|        null|
# |2016-November-Tue...|05:00 pm|     02|        0|Unknown| XXX|     Unknown|
# |2016-November-Tue...|05:00 pm|     01|        0| Female| 032|        Full|
# |2016-November-Tue...|05:40 pm|     02|        0|   Male| 020|     Unknown|
# |2016-November-Tue...|05:40 pm|     01|        0|   Male| 022|     Unknown|
# |2016-November-Monday|11:26 pm|     03|        0|   null|null|        null|
# |2016-November-Monday|11:26 pm|     02|        0|   Male| 042|        Full|
# |2016-November-Monday|11:26 pm|     01|        0|Unknown| XXX|     Unknown|
# |2016-November-Monday|11:30 pm|     03|        0|   Male| 036|        Full|
# |2016-November-Monday|11:30 pm|     02|        0|   Male| 038|        Full|
# |2016-November-Monday|11:30 pm|     01|        0|   Male| 026|     Unknown|
# |2016-November-Tue...|05:05 pm|     02|        0|Unknown| XXX|     Unknown|
# |2016-November-Tue...|05:05 pm|     01|        0|   Male| 025|     Unknown|
# |2016-November-Wed...|03:30 pm|     02|        0|Unknown| XXX|     Unknown|
# |2016-November-Wed...|03:30 pm|     01|        1| Female| 065|        Full|
# |2016-November-Wed...|02:20 pm|     02|        0|   null|null|        null|
# |2016-November-Wed...|02:20 pm|     01|        0|   Male| 063|        Full|
# +--------------------+--------+-------+---------+-------+----+------------+
# only showing top 20 rows
#
# CPU times: user 6.12 ms, sys: 1.22 ms, total: 7.34 ms
# Wall time: 1.52 s

# %%
# 1.
# sql statements for the same tasks

# %%
# %%time
sql_adelaide = spark.sql('''
    SELECT CONCAT(Year, '-', Month, '-', Day) as Date, Time, `Unit No`, `No Of Cas`, Sex, Age, `Licence Type`
    FROM sql_crashes c join sql_units u 
    ON c.REPORT_ID = u.REPORT_ID
    WHERE Suburb == 'ADELAIDE' 
''')
sql_adelaide.show()
# Out:
# +--------------------+--------+-------+---------+-------+----+------------+
# |                Date|    Time|Unit No|No Of Cas|    Sex| Age|Licence Type|
# +--------------------+--------+-------+---------+-------+----+------------+
# |2016-November-Wed...|01:45 pm|     01|        0|   Male| 056|        Full|
# |2016-November-Wed...|01:45 pm|     02|        1|   Male| 072|        null|
# |2016-November-Tue...|03:40 pm|     01|        0|   Male| 056|        null|
# |2016-November-Tue...|03:40 pm|     02|        1| Female| 027|        null|
# |2016-November-Tue...|05:00 pm|     01|        0| Female| 032|        Full|
# |2016-November-Tue...|05:00 pm|     02|        0|Unknown| XXX|     Unknown|
# |2016-November-Tue...|05:40 pm|     01|        0|   Male| 022|     Unknown|
# |2016-November-Tue...|05:40 pm|     02|        0|   Male| 020|     Unknown|
# |2016-November-Monday|11:26 pm|     01|        0|Unknown| XXX|     Unknown|
# |2016-November-Monday|11:26 pm|     02|        0|   Male| 042|        Full|
# |2016-November-Monday|11:26 pm|     03|        0|   null|null|        null|
# |2016-November-Monday|11:30 pm|     01|        0|   Male| 026|     Unknown|
# |2016-November-Monday|11:30 pm|     02|        0|   Male| 038|        Full|
# |2016-November-Monday|11:30 pm|     03|        0|   Male| 036|        Full|
# |2016-November-Tue...|05:05 pm|     01|        0|   Male| 025|     Unknown|
# |2016-November-Tue...|05:05 pm|     02|        0|Unknown| XXX|     Unknown|
# |2016-November-Wed...|03:30 pm|     01|        1| Female| 065|        Full|
# |2016-November-Wed...|03:30 pm|     02|        0|Unknown| XXX|     Unknown|
# |2016-November-Wed...|02:20 pm|     01|        0|   Male| 063|        Full|
# |2016-November-Wed...|02:20 pm|     02|        0|   null|null|        null|
# +--------------------+--------+-------+---------+-------+----+------------+
# only showing top 20 rows
#
# CPU times: user 1.64 ms, sys: 0 ns, total: 1.64 ms
# Wall time: 863 ms

# %%
# 1. 
# rdd statements for the same task
rdd_units_3 = rdd_units_1.map(lambda x: (x.pop(0), x[:]))
rdd_crashes_1 = rdd_crashes.map(lambda x: x.split(","))
rdd_crashes_3 = rdd_crashes_1.map(lambda x: (x.pop(0), x[:]))

# %%
# %%time
rdd_joint = rdd_crashes_3.join(rdd_units_3)
rdd_joint_1 = rdd_joint.map(lambda x: (x[1][0][1], x[1][0][9]+'-'+x[1][0][10]+'-'+x[1][0][11], x[1][0][12], x[1][1][1], x[1][1][6], x[1][1][7], x[1][1][10]))
rdd_filter = rdd_joint_1.filter(lambda x: x[0]=='"ADELAIDE"')
rdd_filter.collect()
# Out:
# CPU times: user 47.4 ms, sys: 1.13 ms, total: 48.6 ms
# Wall time: 6.33 s
# [('"ADELAIDE"',
#   '2019-"January"-"Friday"',
#   '"12:10 am"',
#   '0',
#   '"Male"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"January"-"Friday"',
#   '"12:10 am"',
#   '0',
#   '"Male"',
#   '"033"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"January"-"Thursday"',
#   '"12:15 pm"',
#   '0',
#   '"Male"',
#   '"022"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"January"-"Thursday"',
#   '"12:15 pm"',
#   '0',
#   '"Female"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"February"-"Tuesday"',
#   '"11:05 am"',
#   '0',
#   '"Male"',
#   '"050"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"February"-"Tuesday"',
#   '"11:05 am"',
#   '0',
#   '"Male"',
#   '"041"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"February"-"Tuesday"',
#   '"07:35 pm"',
#   '1',
#   '"Male"',
#   '"018"',
#   '"Learners"'),
#  ('"ADELAIDE"', '2019-"February"-"Tuesday"', '"07:35 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"March"-"Saturday"',
#   '"03:41 pm"',
#   '0',
#   '"Male"',
#   '"018"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2019-"March"-"Saturday"',
#   '"03:41 pm"',
#   '0',
#   '"Male"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"March"-"Saturday"',
#   '"03:41 pm"',
#   '0',
#   '"Male"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"March"-"Thursday"',
#   '"06:40 pm"',
#   '0',
#   '"Male"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"March"-"Thursday"',
#   '"06:40 pm"',
#   '1',
#   '"Female"',
#   '"060"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"March"-"Friday"',
#   '"06:30 pm"',
#   '0',
#   '"Female"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"March"-"Friday"',
#   '"06:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"March"-"Thursday"',
#   '"04:55 pm"',
#   '0',
#   '"Female"',
#   '"034"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"March"-"Thursday"',
#   '"04:55 pm"',
#   '0',
#   '"Male"',
#   '"057"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"April"-"Monday"',
#   '"07:15 am"',
#   '0',
#   '"Female"',
#   '"024"',
#   '"Full"'),
#  ('"ADELAIDE"', '2019-"April"-"Monday"', '"07:15 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"April"-"Monday"',
#   '"05:41 pm"',
#   '1',
#   '"Male"',
#   '"020"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Monday"',
#   '"05:41 pm"',
#   '0',
#   '"Male"',
#   '"019"',
#   '"Provisional 1 "'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Tuesday"',
#   '"10:00 am"',
#   '0',
#   '"Male"',
#   '"062"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Tuesday"',
#   '"10:00 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"April"-"Thursday"',
#   '"04:50 pm"',
#   '0',
#   '"Female"',
#   '"041"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Thursday"',
#   '"04:50 pm"',
#   '1',
#   '"Female"',
#   '"017"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"April"-"Friday"',
#   '"03:13 pm"',
#   '1',
#   '"Male"',
#   '"020"',
#   '"Learners"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Friday"',
#   '"03:13 pm"',
#   '0',
#   '"Male"',
#   '"072"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Sunday"',
#   '"02:40 am"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Sunday"',
#   '"02:40 am"',
#   '1',
#   '"Male"',
#   '"024"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"April"-"Saturday"',
#   '"03:00 pm"',
#   '0',
#   '"Female"',
#   '"035"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Saturday"',
#   '"03:00 pm"',
#   '0',
#   '"Female"',
#   '"034"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Thursday"',
#   '"02:30 am"',
#   '0',
#   '"Female"',
#   '"019"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Thursday"',
#   '"02:30 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Tuesday"',
#   '"07:09 pm"',
#   '1',
#   '"Female"',
#   '"023"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2019-"April"-"Tuesday"',
#   '"07:09 pm"',
#   '0',
#   '"Female"',
#   '"019"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Thursday"',
#   '"05:49 am"',
#   '0',
#   '"Male"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Thursday"',
#   '"05:49 am"',
#   '0',
#   '"Male"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Monday"',
#   '"01:45 pm"',
#   '0',
#   '"Male"',
#   '"048"',
#   '"Full"'),
#  ('"ADELAIDE"', '2019-"May"-"Monday"', '"01:45 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"May"-"Wednesday"',
#   '"10:00 pm"',
#   '0',
#   '"Male"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Wednesday"',
#   '"10:00 pm"',
#   '0',
#   '"Female"',
#   '"049"',
#   '"Learners"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Thursday"',
#   '"05:40 am"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"', '2019-"May"-"Thursday"', '"05:40 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"May"-"Tuesday"',
#   '"08:45 am"',
#   '0',
#   '"Female"',
#   '"024"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Tuesday"',
#   '"08:45 am"',
#   '0',
#   '"Female"',
#   '"058"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Friday"',
#   '"05:40 pm"',
#   '1',
#   '"Male"',
#   '"034"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"May"-"Friday"',
#   '"05:40 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Friday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"025"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"May"-"Friday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Friday"',
#   '"05:05 pm"',
#   '0',
#   '"Male"',
#   '"070"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Friday"',
#   '"05:05 pm"',
#   '0',
#   '"Male"',
#   '"030"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Thursday"',
#   '"10:00 am"',
#   '0',
#   '"Female"',
#   '"038"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Thursday"',
#   '"10:00 am"',
#   '1',
#   '"Male"',
#   '"042"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"June"-"Friday"',
#   '"09:32 pm"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Friday"',
#   '"09:32 pm"',
#   '0',
#   '"Female"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Monday"',
#   '"10:00 am"',
#   '0',
#   '"Female"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Monday"',
#   '"10:00 am"',
#   '1',
#   '"Female"',
#   '"063"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"June"-"Friday"',
#   '"01:20 pm"',
#   '0',
#   '"Male"',
#   '"048"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"June"-"Friday"',
#   '"01:20 pm"',
#   '0',
#   '"Male"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"July"-"Wednesday"',
#   '"04:48 pm"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"July"-"Wednesday"',
#   '"04:48 pm"',
#   '0',
#   '"Male"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"July"-"Wednesday"',
#   '"04:48 pm"',
#   '0',
#   '"Male"',
#   '"047"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"July"-"Wednesday"',
#   '"06:15 pm"',
#   '0',
#   '"Female"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"July"-"Wednesday"',
#   '"06:15 pm"',
#   '1',
#   '"Female"',
#   '"028"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"July"-"Friday"',
#   '"10:00 pm"',
#   '0',
#   '"Male"',
#   '"082"',
#   '"Full"'),
#  ('"ADELAIDE"', '2019-"July"-"Friday"', '"10:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"July"-"Wednesday"',
#   '"04:40 pm"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"July"-"Wednesday"',
#   '"04:40 pm"',
#   '1',
#   '"Female"',
#   '"023"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"July"-"Sunday"',
#   '"01:41 pm"',
#   '0',
#   '"Male"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"July"-"Sunday"',
#   '"01:41 pm"',
#   '1',
#   '"Female"',
#   '"020"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"August"-"Sunday"',
#   '"08:30 am"',
#   '0',
#   '"Male"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Sunday"',
#   '"08:30 am"',
#   '0',
#   '"Male"',
#   '"033"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Monday"',
#   '"09:10 am"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Monday"',
#   '"09:10 am"',
#   '0',
#   '"Male"',
#   '"064"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Thursday"',
#   '"10:00 am"',
#   '1',
#   '"Female"',
#   '"062"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"August"-"Tuesday"',
#   '"12:50 pm"',
#   '0',
#   '"Male"',
#   '"068"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Tuesday"',
#   '"12:50 pm"',
#   '0',
#   '"Female"',
#   '"021"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"August"-"Friday"',
#   '"02:50 pm"',
#   '0',
#   '"Female"',
#   '"073"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Friday"',
#   '"02:50 pm"',
#   '0',
#   '"Female"',
#   '"070"',
#   '"Full"'),
#  ('"ADELAIDE"', '2019-"August"-"Friday"', '"02:50 pm"', '0', '', '', ''),
#  ('"ADELAIDE"', '2019-"August"-"Friday"', '"02:50 pm"', '0', '', '', ''),
#  ('"ADELAIDE"', '2019-"August"-"Friday"', '"02:50 pm"', '0', '', '', ''),
#  ('"ADELAIDE"', '2019-"August"-"Friday"', '"02:50 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"August"-"Wednesday"',
#   '"08:00 am"',
#   '0',
#   '"Male"',
#   '"034"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Wednesday"',
#   '"08:00 am"',
#   '1',
#   '"Female"',
#   '"018"',
#   ''),
#  ('"ADELAIDE"', '2019-"August"-"Tuesday"', '"06:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"August"-"Tuesday"',
#   '"06:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Tuesday"',
#   '"08:40 am"',
#   '0',
#   '"Female"',
#   '"063"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"August"-"Tuesday"',
#   '"08:40 am"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"September"-"Saturday"',
#   '"11:40 pm"',
#   '0',
#   '"Female"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"September"-"Saturday"',
#   '"11:40 pm"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Wednesday"',
#   '"05:20 pm"',
#   '0',
#   '"Female"',
#   '"020"',
#   '"Unlicenced"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Wednesday"',
#   '"05:20 pm"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '0-2019-"October"',
#   '"Friday"',
#   '0',
#   '"Male"',
#   '"063"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '0-2019-"October"',
#   '"Friday"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Tuesday"',
#   '"11:30 am"',
#   '0',
#   '"Female"',
#   '"025"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Tuesday"',
#   '"11:30 am"',
#   '1',
#   '"Female"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Monday"',
#   '"08:20 am"',
#   '1',
#   '"Male"',
#   '"048"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Monday"',
#   '"08:20 am"',
#   '5',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Monday"',
#   '"08:20 am"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Monday"',
#   '"08:20 am"',
#   '0',
#   '"Male"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Wednesday"',
#   '"02:00 pm"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Wednesday"',
#   '"02:00 pm"',
#   '0',
#   '"Male"',
#   '"063"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Wednesday"',
#   '"10:30 pm"',
#   '0',
#   '"Male"',
#   '"025"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"October"-"Wednesday"',
#   '"10:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Friday"',
#   '"09:33 am"',
#   '1',
#   '"Male"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Friday"',
#   '"09:33 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Monday"',
#   '"12:10 pm"',
#   '0',
#   '"Male"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Monday"',
#   '"12:10 pm"',
#   '1',
#   '"Female"',
#   '"077"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"November"-"Tuesday"',
#   '"03:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"', '2019-"November"-"Tuesday"', '"03:30 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"November"-"Thursday"',
#   '"05:50 pm"',
#   '0',
#   '"Female"',
#   '"022"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Thursday"',
#   '"05:50 pm"',
#   '0',
#   '"Male"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Friday"',
#   '"10:05 pm"',
#   '0',
#   '"Male"',
#   '"046"',
#   '"Full"'),
#  ('"ADELAIDE"', '2019-"November"-"Friday"', '"10:05 pm"', '0', '', '', ''),
#  ('"ADELAIDE"', '2019-"November"-"Friday"', '"10:05 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2019-"November"-"Sunday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"019"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Sunday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Monday"',
#   '"02:21 pm"',
#   '0',
#   '"Male"',
#   '"021"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2019-"November"-"Monday"',
#   '"02:21 pm"',
#   '1',
#   '"Female"',
#   '"037"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"December"-"Monday"',
#   '"08:48 am"',
#   '0',
#   '"Male"',
#   '"067"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Monday"',
#   '"08:48 am"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Friday"',
#   '"11:50 pm"',
#   '0',
#   '"Male"',
#   '"026"',
#   ''),
#  ('"ADELAIDE"',
#   '2019-"December"-"Friday"',
#   '"11:50 pm"',
#   '0',
#   '"Male"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Friday"',
#   '"04:10 pm"',
#   '0',
#   '"Male"',
#   '"061"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Friday"',
#   '"04:10 pm"',
#   '0',
#   '"Male"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Monday"',
#   '"12:20 pm"',
#   '0',
#   '"Female"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Monday"',
#   '"12:20 pm"',
#   '0',
#   '"Male"',
#   '"063"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Tuesday"',
#   '"09:15 am"',
#   '0',
#   '"Male"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2019-"December"-"Tuesday"',
#   '"09:15 am"',
#   '0',
#   '"Male"',
#   '"051"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"05:00 pm"',
#   '0',
#   '"Female"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"05:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Friday"',
#   '"11:00 am"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Friday"',
#   '"11:00 am"',
#   '0',
#   '"Male"',
#   '"038"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Saturday"',
#   '"09:00 pm"',
#   '0',
#   '"Male"',
#   '"030"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Saturday"',
#   '"09:00 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"', '2016-"December"-"Saturday"', '"10:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"December"-"Saturday"',
#   '"10:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Tuesday"',
#   '"05:43 pm"',
#   '0',
#   '"Female"',
#   '"039"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Tuesday"',
#   '"05:43 pm"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"10:45 am"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"10:45 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"05:21 pm"',
#   '0',
#   '"Female"',
#   '"048"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"05:21 pm"',
#   '0',
#   '"Female"',
#   '"036"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"05:21 pm"',
#   '0',
#   '"Female"',
#   '"025"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Thursday"',
#   '"11:30 am"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Thursday"',
#   '"11:30 am"',
#   '0',
#   '"Male"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Sunday"',
#   '"01:56 pm"',
#   '0',
#   '"Male"',
#   '"068"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Sunday"',
#   '"01:56 pm"',
#   '1',
#   '"Male"',
#   '"049"',
#   ''),
#  ('"ADELAIDE"', '2016-"December"-"Sunday"', '"01:56 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"11:48 am"',
#   '0',
#   '"Female"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"11:48 am"',
#   '0',
#   '"Male"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"December"-"Wednesday"',
#   '"11:48 am"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Sunday"',
#   '"05:45 pm"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"January"-"Sunday"', '"05:45 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"February"-"Tuesday"',
#   '"04:00 pm"',
#   '0',
#   '"Male"',
#   '"033"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"February"-"Tuesday"',
#   '"04:00 pm"',
#   '1',
#   '"Male"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Thursday"',
#   '"12:50 pm"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Thursday"',
#   '"12:50 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"March"-"Friday"',
#   '"09:35 am"',
#   '0',
#   '"Male"',
#   '"057"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Friday"',
#   '"09:35 am"',
#   '0',
#   '"Female"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Tuesday"',
#   '"01:00 pm"',
#   '0',
#   '"Male"',
#   '"033"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Tuesday"',
#   '"01:00 pm"',
#   '0',
#   '"Male"',
#   '"025"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"May"-"Friday"',
#   '"07:20 am"',
#   '0',
#   '"Male"',
#   '"035"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Friday"',
#   '"07:20 am"',
#   '0',
#   '"Female"',
#   '"026"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Wednesday"',
#   '"09:30 am"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"August"-"Wednesday"', '"09:30 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"September"-"Sunday"',
#   '"11:30 am"',
#   '0',
#   '"Female"',
#   '"058"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Sunday"',
#   '"11:30 am"',
#   '0',
#   '"Male"',
#   '"060"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Saturday"',
#   '"12:20 pm"',
#   '0',
#   '"Female"',
#   '"048"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Saturday"',
#   '"12:20 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"January"-"Saturday"',
#   '"11:10 am"',
#   '0',
#   '"Male"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Saturday"',
#   '"11:10 am"',
#   '0',
#   '"Female"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '1-2016-"January"',
#   '"Thursday"',
#   '1',
#   '"Male"',
#   '"017"',
#   '"Provisional 1 "'),
#  ('"ADELAIDE"',
#   '1-2016-"January"',
#   '"Thursday"',
#   '0',
#   '"Female"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Wednesday"',
#   '"05:40 pm"',
#   '0',
#   '"Female"',
#   '"038"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Wednesday"',
#   '"05:40 pm"',
#   '0',
#   '"Male"',
#   '"030"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"January"-"Wednesday"',
#   '"01:30 pm"',
#   '1',
#   '"Female"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Wednesday"',
#   '"01:30 pm"',
#   '0',
#   '"Male"',
#   '"053"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Wednesday"',
#   '"08:30 am"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Wednesday"',
#   '"08:30 am"',
#   '0',
#   '"Male"',
#   '"020"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"January"-"Friday"',
#   '"11:17 am"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"January"-"Friday"', '"11:17 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"February"-"Tuesday"',
#   '"08:20 am"',
#   '0',
#   '"Male"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"February"-"Tuesday"',
#   '"08:20 am"',
#   '0',
#   '"Male"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"February"-"Wednesday"',
#   '"01:45 pm"',
#   '0',
#   '"Male"',
#   '"041"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"February"-"Wednesday"',
#   '"01:45 pm"',
#   '0',
#   '"Male"',
#   '"033"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"February"-"Thursday"',
#   '"05:00 pm"',
#   '0',
#   '"Female"',
#   '"019"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"February"-"Thursday"',
#   '"05:00 pm"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"February"-"Tuesday"',
#   '"03:30 pm"',
#   '1',
#   '"Female"',
#   '"023"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"February"-"Tuesday"',
#   '"03:30 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Wednesday"',
#   '"05:00 am"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Wednesday"',
#   '"05:00 am"',
#   '0',
#   '"Male"',
#   '"027"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"March"-"Sunday"',
#   '"02:30 pm"',
#   '0',
#   '"Male"',
#   '"026"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"March"-"Sunday"',
#   '"02:30 pm"',
#   '0',
#   '"Male"',
#   '"083"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Tuesday"',
#   '"09:30 am"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Tuesday"',
#   '"09:30 am"',
#   '0',
#   '"Male"',
#   '"077"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"March"-"Tuesday"', '"09:30 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"March"-"Tuesday"',
#   '"09:30 am"',
#   '0',
#   '"Male"',
#   '"019"',
#   '"Unlicenced"'),
#  ('"ADELAIDE"', '2016-"March"-"Tuesday"', '"09:30 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"March"-"Tuesday"',
#   '"09:30 am"',
#   '0',
#   '"Male"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Tuesday"',
#   '"09:45 am"',
#   '0',
#   '"Female"',
#   '"034"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"April"-"Tuesday"',
#   '"09:45 am"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"April"-"Friday"',
#   '"01:08 pm"',
#   '0',
#   '"Female"',
#   '"065"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Friday"',
#   '"01:08 pm"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"11:15 am"',
#   '0',
#   '"Female"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"11:15 am"',
#   '0',
#   '"Female"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Tuesday"',
#   '"05:30 pm"',
#   '0',
#   '"Female"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Tuesday"',
#   '"05:30 pm"',
#   '0',
#   '"Female"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Tuesday"',
#   '"05:55 pm"',
#   '0',
#   '"Male"',
#   '"041"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Tuesday"',
#   '"05:55 pm"',
#   '0',
#   '"Female"',
#   '"025"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"May"-"Thursday"', '"09:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"May"-"Thursday"',
#   '"09:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Friday"',
#   '"03:20 pm"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Friday"',
#   '"03:20 pm"',
#   '0',
#   '"Female"',
#   '"020"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Sunday"',
#   '"10:45 am"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Sunday"',
#   '"10:45 am"',
#   '0',
#   '"Female"',
#   '"054"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Friday"',
#   '"01:30 pm"',
#   '0',
#   '"Male"',
#   '"053"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"May"-"Friday"',
#   '"01:30 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"May"-"Monday"',
#   '"06:20 pm"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Monday"',
#   '"06:20 pm"',
#   '0',
#   '"Female"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Sunday"',
#   '"12:45 pm"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Sunday"',
#   '"12:45 pm"',
#   '0',
#   '"Male"',
#   '"051"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Tuesday"',
#   '"02:30 pm"',
#   '0',
#   '"Female"',
#   '"069"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Tuesday"',
#   '"02:30 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Thursday"',
#   '"04:05 pm"',
#   '0',
#   '"Male"',
#   '"041"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Thursday"',
#   '"04:05 pm"',
#   '0',
#   '"Male"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Friday"',
#   '"01:25 pm"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Friday"',
#   '"01:25 pm"',
#   '0',
#   '"Male"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Thursday"',
#   '"05:10 pm"',
#   '0',
#   '"Male"',
#   '"031"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"June"-"Thursday"',
#   '"05:10 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Sunday"',
#   '"01:30 pm"',
#   '0',
#   '"Female"',
#   '"020"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Sunday"',
#   '"01:30 pm"',
#   '1',
#   '"Male"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Friday"',
#   '"09:10 am"',
#   '0',
#   '"Male"',
#   '"051"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Friday"',
#   '"09:10 am"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Friday"',
#   '"12:01 am"',
#   '1',
#   '"Unknown"',
#   '"023"',
#   '"Disqualified"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Friday"',
#   '"12:01 am"',
#   '0',
#   '"Male"',
#   '"046"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"July"-"Friday"', '"12:01 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"July"-"Friday"',
#   '"06:50 pm"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Friday"',
#   '"06:50 pm"',
#   '0',
#   '"Male"',
#   '"037"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Sunday"',
#   '"12:10 pm"',
#   '1',
#   '"Male"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Wednesday"',
#   '"04:18 pm"',
#   '0',
#   '"Female"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Wednesday"',
#   '"04:18 pm"',
#   '0',
#   '"Female"',
#   '"083"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Tuesday"',
#   '"05:30 pm"',
#   '0',
#   '"Male"',
#   '"041"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Tuesday"',
#   '"05:30 pm"',
#   '1',
#   '"Female"',
#   '"045"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"July"-"Sunday"',
#   '"10:23 pm"',
#   '0',
#   '"Male"',
#   '"020"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Sunday"',
#   '"10:23 pm"',
#   '0',
#   '"Male"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Thursday"',
#   '"04:30 pm"',
#   '0',
#   '"Female"',
#   '"030"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Thursday"',
#   '"04:30 pm"',
#   '0',
#   '"Male"',
#   '"047"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Friday"',
#   '"07:30 am"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Friday"',
#   '"07:30 am"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Monday"',
#   '"09:30 am"',
#   '1',
#   '"Male"',
#   '"023"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"August"-"Monday"',
#   '"09:30 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Saturday"',
#   '"12:51 pm"',
#   '0',
#   '"Male"',
#   '"066"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Saturday"',
#   '"12:51 pm"',
#   '0',
#   '"Male"',
#   '"019"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Monday"',
#   '"09:45 pm"',
#   '0',
#   '"Female"',
#   '"031"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"August"-"Monday"',
#   '"09:45 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Wednesday"',
#   '"12:20 pm"',
#   '0',
#   '"Male"',
#   '"079"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Wednesday"',
#   '"12:20 pm"',
#   '0',
#   '"Female"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Friday"',
#   '"05:00 pm"',
#   '0',
#   '"Male"',
#   '"057"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Friday"',
#   '"05:00 pm"',
#   '0',
#   '"Female"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Monday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"032"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"September"-"Monday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Monday"',
#   '"08:20 am"',
#   '0',
#   '"Male"',
#   '"060"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Monday"',
#   '"08:20 am"',
#   '0',
#   '"Male"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Tuesday"',
#   '"05:45 pm"',
#   '0',
#   '"Female"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Tuesday"',
#   '"05:45 pm"',
#   '0',
#   '"Female"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"October"-"Tuesday"',
#   '"10:25 pm"',
#   '0',
#   '"Female"',
#   '"022"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"October"-"Tuesday"',
#   '"10:25 pm"',
#   '1',
#   '"Male"',
#   '"020"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"October"-"Wednesday"',
#   '"04:35 pm"',
#   '0',
#   '"Female"',
#   '"047"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"October"-"Wednesday"',
#   '"04:35 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"October"-"Wednesday"',
#   '"06:10 pm"',
#   '0',
#   '"Female"',
#   '"048"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"October"-"Wednesday"',
#   '"06:10 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"November"-"Friday"',
#   '"11:00 am"',
#   '0',
#   '"Female"',
#   '"025"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Friday"',
#   '"11:00 am"',
#   '0',
#   '"Male"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"01:30 pm"',
#   '1',
#   '"Male"',
#   '"051"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"01:30 pm"',
#   '0',
#   '"Female"',
#   '"021"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Wednesday"',
#   '"06:45 pm"',
#   '0',
#   '"Female"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Wednesday"',
#   '"06:45 pm"',
#   '0',
#   '"Male"',
#   '"047"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"November"-"Thursday"', '"07:00 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"November"-"Thursday"',
#   '"07:00 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Friday"',
#   '"08:50 am"',
#   '0',
#   '"Male"',
#   '"053"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Friday"',
#   '"08:50 am"',
#   '0',
#   '"Male"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Sunday"',
#   '"03:30 pm"',
#   '0',
#   '"Male"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Sunday"',
#   '"03:30 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"03:20 pm"',
#   '0',
#   '"Male"',
#   '"063"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"03:20 pm"',
#   '0',
#   '"Female"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Monday"',
#   '"07:15 pm"',
#   '0',
#   '"Female"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Monday"',
#   '"07:15 pm"',
#   '0',
#   '"Female"',
#   '"046"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Saturday"',
#   '"04:41 am"',
#   '1',
#   '"Male"',
#   '"034"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Saturday"',
#   '"04:41 am"',
#   '0',
#   '"Female"',
#   '"019"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Thursday"',
#   '"01:50 pm"',
#   '1',
#   '"Female"',
#   '"046"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Thursday"',
#   '"01:50 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"', '2017-"February"-"Saturday"', '"03:30 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Saturday"',
#   '"03:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"', '2017-"February"-"Tuesday"', '"09:00 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Tuesday"',
#   '"09:00 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Thursday"',
#   '"04:30 pm"',
#   '0',
#   '"Male"',
#   '"021"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Thursday"',
#   '"04:30 pm"',
#   '0',
#   '"Female"',
#   '"046"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Thursday"',
#   '"04:30 pm"',
#   '0',
#   '"Male"',
#   '"060"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Wednesday"',
#   '"09:55 am"',
#   '1',
#   '"Male"',
#   '"079"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Wednesday"',
#   '"09:55 am"',
#   '0',
#   '"Female"',
#   '"080"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Monday"',
#   '"01:20 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Monday"',
#   '"01:20 pm"',
#   '0',
#   '"Female"',
#   '"071"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Monday"',
#   '"02:00 pm"',
#   '0',
#   '"Male"',
#   '"020"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Monday"',
#   '"02:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Wednesday"',
#   '"08:45 am"',
#   '0',
#   '"Male"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Wednesday"',
#   '"08:45 am"',
#   '0',
#   '"Male"',
#   '"064"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"08:10 am"',
#   '0',
#   '"Female"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"08:10 am"',
#   '0',
#   '"Male"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Wednesday"',
#   '"12:00 pm"',
#   '1',
#   '"Male"',
#   '"024"',
#   ''),
#  ('"ADELAIDE"', '2017-"March"-"Wednesday"', '"12:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"March"-"Tuesday"',
#   '"10:00 am"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Tuesday"',
#   '"10:00 am"',
#   '0',
#   '"Male"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Friday"',
#   '"06:15 pm"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Friday"',
#   '"06:15 pm"',
#   '0',
#   '"Male"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Friday"',
#   '"08:50 am"',
#   '0',
#   '"Female"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Friday"',
#   '"08:50 am"',
#   '0',
#   '"Female"',
#   '"058"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Tuesday"',
#   '"11:00 am"',
#   '0',
#   '"Male"',
#   '"032"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Tuesday"',
#   '"11:00 am"',
#   '0',
#   '"Female"',
#   '"054"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Thursday"',
#   '"05:49 pm"',
#   '0',
#   '"Female"',
#   '"053"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Thursday"',
#   '"05:49 pm"',
#   '0',
#   '"Male"',
#   '"058"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Thursday"',
#   '"11:20 am"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Thursday"',
#   '"11:20 am"',
#   '0',
#   '"Male"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Friday"',
#   '"08:11 am"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Friday"',
#   '"08:11 am"',
#   '0',
#   '"Male"',
#   '"083"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Friday"',
#   '"08:11 am"',
#   '0',
#   '"Male"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Friday"',
#   '"10:44 am"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Friday"',
#   '"10:44 am"',
#   '0',
#   '"Female"',
#   '"056"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Wednesday"',
#   '"01:15 pm"',
#   '0',
#   '"Female"',
#   '"020"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Wednesday"',
#   '"01:15 pm"',
#   '0',
#   '"Male"',
#   '"063"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Wednesday"',
#   '"06:30 pm"',
#   '0',
#   '"Male"',
#   '"088"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Wednesday"',
#   '"06:30 pm"',
#   '1',
#   '"Female"',
#   '"063"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"June"-"Friday"',
#   '"06:57 am"',
#   '0',
#   '"Male"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"', '2017-"June"-"Friday"', '"06:57 am"', '0', '', '', ''),
#  ('"ADELAIDE"', '2017-"June"-"Friday"', '"06:57 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"June"-"Friday"',
#   '"06:00 pm"',
#   '0',
#   '"Female"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Friday"',
#   '"06:00 pm"',
#   '0',
#   '"Female"',
#   '"021"',
#   '"Provisional 1 "'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Wednesday"',
#   '"03:55 pm"',
#   '0',
#   '"Male"',
#   '"065"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Wednesday"',
#   '"03:55 pm"',
#   '0',
#   '"Female"',
#   '"060"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Wednesday"',
#   '"03:55 pm"',
#   '0',
#   '"Male"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Friday"',
#   '"08:00 am"',
#   '0',
#   '"Male"',
#   '"035"',
#   '"Unlicenced"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Friday"',
#   '"08:00 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Saturday"',
#   '"03:20 am"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Saturday"',
#   '"03:20 am"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Tuesday"',
#   '"01:45 pm"',
#   '0',
#   '"Male"',
#   '"027"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"July"-"Tuesday"',
#   '"01:45 pm"',
#   '0',
#   '"Male"',
#   '"056"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Tuesday"',
#   '"04:15 pm"',
#   '1',
#   '"Male"',
#   '"035"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Tuesday"',
#   '"04:15 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Friday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Friday"',
#   '"05:15 pm"',
#   '0',
#   '"Female"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Sunday"',
#   '"05:15 pm"',
#   '0',
#   '"Male"',
#   '"030"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Sunday"',
#   '"05:15 pm"',
#   '1',
#   '"Male"',
#   '"XXX"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Saturday"',
#   '"01:51 am"',
#   '1',
#   '"Male"',
#   '"047"',
#   '"Unknown"'),
#  ('"ADELAIDE"', '2017-"August"-"Saturday"', '"01:51 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"August"-"Saturday"',
#   '"01:51 am"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Wednesday"',
#   '"03:30 pm"',
#   '0',
#   '"Male"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Wednesday"',
#   '"03:30 pm"',
#   '0',
#   '"Female"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Wednesday"',
#   '"03:30 pm"',
#   '0',
#   '"Male"',
#   '"058"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"September"-"Saturday"',
#   '"02:09 pm"',
#   '0',
#   '"Female"',
#   '"030"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"September"-"Saturday"',
#   '"02:09 pm"',
#   '0',
#   '"Male"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"September"-"Tuesday"',
#   '"09:00 am"',
#   '0',
#   '"Female"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"September"-"Tuesday"',
#   '"09:00 am"',
#   '0',
#   '"Male"',
#   '"057"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"September"-"Thursday"',
#   '"05:40 pm"',
#   '0',
#   '"Male"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"September"-"Thursday"',
#   '"05:40 pm"',
#   '1',
#   '"Male"',
#   '"004"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"September"-"Wednesday"',
#   '"04:50 pm"',
#   '0',
#   '"Male"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"', '2017-"September"-"Wednesday"', '"04:50 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"September"-"Wednesday"',
#   '"04:50 pm"',
#   '0',
#   '"Female"',
#   '"057"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Tuesday"',
#   '"06:00 pm"',
#   '0',
#   '"Female"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Tuesday"',
#   '"06:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Wednesday"',
#   '"12:55 pm"',
#   '0',
#   '"Male"',
#   '"064"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Wednesday"',
#   '"12:55 pm"',
#   '0',
#   '"Female"',
#   '"084"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Thursday"',
#   '"07:00 am"',
#   '0',
#   '"Female"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Thursday"',
#   '"07:00 am"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Friday"',
#   '"10:30 pm"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Friday"',
#   '"10:30 pm"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Monday"',
#   '"06:10 pm"',
#   '1',
#   '"Male"',
#   '"052"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"October"-"Monday"',
#   '"06:10 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Wednesday"',
#   '"09:05 am"',
#   '0',
#   '"Male"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"October"-"Wednesday"',
#   '"09:05 am"',
#   '1',
#   '"Male"',
#   '"029"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"November"-"Wednesday"',
#   '"10:30 am"',
#   '0',
#   '"Male"',
#   '"020"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2017-"November"-"Wednesday"',
#   '"10:30 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"November"-"Wednesday"',
#   '"10:16 am"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"November"-"Wednesday"',
#   '"10:16 am"',
#   '1',
#   '"Male"',
#   '"018"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"November"-"Wednesday"',
#   '"12:30 pm"',
#   '0',
#   '"Male"',
#   '"057"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"November"-"Wednesday"',
#   '"12:30 pm"',
#   '0',
#   '"Male"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"November"-"Friday"',
#   '"03:37 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"', '2017-"November"-"Friday"', '"03:37 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"December"-"Friday"',
#   '"08:32 am"',
#   '0',
#   '"Male"',
#   '"062"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Friday"',
#   '"08:32 am"',
#   '0',
#   '"Female"',
#   '"060"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Wednesday"',
#   '"06:36 pm"',
#   '0',
#   '"Female"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Wednesday"',
#   '"06:36 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Wednesday"',
#   '"08:35 pm"',
#   '0',
#   '"Female"',
#   '"023"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Wednesday"',
#   '"08:35 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Wednesday"',
#   '"08:00 pm"',
#   '0',
#   '"Male"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Wednesday"',
#   '"08:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"December"-"Friday"',
#   '"11:00 am"',
#   '1',
#   '"Male"',
#   '"028"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"December"-"Friday"',
#   '"11:00 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"January"-"Sunday"',
#   '"02:00 pm"',
#   '0',
#   '"Male"',
#   '"047"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"January"-"Sunday"',
#   '"02:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Friday"',
#   '"10:30 pm"',
#   '1',
#   '"Male"',
#   '"017"',
#   '"Learners"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Friday"',
#   '"10:30 pm"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Friday"',
#   '"10:30 pm"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"February"-"Friday"', '"10:30 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Tuesday"',
#   '"06:45 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Tuesday"',
#   '"06:45 am"',
#   '1',
#   '"Male"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Friday"',
#   '"04:20 pm"',
#   '0',
#   '"Female"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Friday"',
#   '"04:20 pm"',
#   '0',
#   '"Male"',
#   '"065"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"February"-"Friday"', '"04:20 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Saturday"',
#   '"06:30 pm"',
#   '0',
#   '"Male"',
#   '"059"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Saturday"',
#   '"06:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Monday"',
#   '"10:30 pm"',
#   '0',
#   '"Female"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"February"-"Monday"', '"10:30 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Monday"',
#   '"10:30 pm"',
#   '1',
#   '"Female"',
#   '"028"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Monday"',
#   '"10:30 pm"',
#   '1',
#   '"Female"',
#   '"034"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Tuesday"',
#   '"07:40 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"February"-"Tuesday"',
#   '"07:40 am"',
#   '0',
#   '"Male"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Wednesday"',
#   '"08:10 am"',
#   '1',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"February"-"Wednesday"',
#   '"08:10 am"',
#   '0',
#   '"Female"',
#   '"025"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Monday"',
#   '"09:05 am"',
#   '0',
#   '"Female"',
#   '"XXX"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Monday"',
#   '"09:05 am"',
#   '1',
#   '"Female"',
#   '"050"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"March"-"Wednesday"',
#   '"01:10 pm"',
#   '0',
#   '"Male"',
#   '"064"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Wednesday"',
#   '"01:10 pm"',
#   '0',
#   '"Female"',
#   '"069"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"March"-"Thursday"', '"12:15 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"March"-"Thursday"',
#   '"12:15 pm"',
#   '1',
#   '"Female"',
#   '"033"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"March"-"Thursday"',
#   '"08:15 am"',
#   '0',
#   '"Female"',
#   '"026"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Thursday"',
#   '"08:15 am"',
#   '1',
#   '"Male"',
#   '"029"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"March"-"Thursday"',
#   '"01:20 pm"',
#   '0',
#   '"Female"',
#   '"065"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Thursday"',
#   '"01:20 pm"',
#   '0',
#   '"Male"',
#   '"051"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"March"-"Thursday"',
#   '"04:35 pm"',
#   '0',
#   '"Male"',
#   '"054"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Thursday"',
#   '"04:35 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Monday"',
#   '"12:43 pm"',
#   '0',
#   '"Male"',
#   '"065"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Monday"',
#   '"12:43 pm"',
#   '0',
#   '"Male"',
#   '"025"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"March"-"Monday"',
#   '"12:43 pm"',
#   '0',
#   '"Male"',
#   '"036"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"April"-"Tuesday"',
#   '"03:45 pm"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"April"-"Tuesday"',
#   '"03:45 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"April"-"Wednesday"',
#   '"04:40 am"',
#   '0',
#   '"Male"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"April"-"Wednesday"', '"04:40 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"April"-"Friday"',
#   '"05:40 pm"',
#   '1',
#   '"Male"',
#   '"039"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"April"-"Friday"',
#   '"05:40 pm"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"April"-"Tuesday"',
#   '"07:40 am"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"April"-"Tuesday"',
#   '"07:40 am"',
#   '1',
#   '"Male"',
#   '"030"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"May"-"Wednesday"',
#   '"02:35 pm"',
#   '1',
#   '"Male"',
#   '"029"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"May"-"Wednesday"',
#   '"02:35 pm"',
#   '0',
#   '"Male"',
#   '"064"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"May"-"Sunday"', '"05:30 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"May"-"Sunday"',
#   '"05:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"May"-"Wednesday"',
#   '"08:30 pm"',
#   '1',
#   '"Female"',
#   '"038"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"May"-"Wednesday"',
#   '"08:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2018-"May"-"Saturday"',
#   '"07:00 pm"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"May"-"Saturday"',
#   '"07:00 pm"',
#   '0',
#   '"Male"',
#   '"018"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2018-"May"-"Tuesday"',
#   '"04:20 am"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"May"-"Tuesday"', '"04:20 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"May"-"Friday"',
#   '"11:30 am"',
#   '0',
#   '"Male"',
#   '"058"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"May"-"Friday"',
#   '"11:30 am"',
#   '1',
#   '"Male"',
#   '"080"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"May"-"Friday"',
#   '"11:30 am"',
#   '0',
#   '"Male"',
#   '"024"',
#   '"Full"'),
#  ('"ADELAIDE"', '2018-"May"-"Friday"', '"11:30 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"June"-"Friday"',
#   '"04:20 pm"',
#   '0',
#   '"Male"',
#   '"018"',
#   '"Provisional 1 "'),
#  ('"ADELAIDE"', '2018-"June"-"Friday"', '"04:20 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2018-"June"-"Friday"',
#   '"10:00 pm"',
#   '0',
#   '"Male"',
#   '"020"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2018-"June"-"Friday"',
#   '"10:00 pm"',
#   '0',
#   '"Female"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"June"-"Friday"',
#   '"10:00 pm"',
#   '0',
#   '"Female"',
#   '"XXX"',
#   ''),
#  ('"ADELAIDE"',
#   '2018-"June"-"Saturday"',
#   '"02:55 pm"',
#   '2',
#   '"Male"',
#   '"083"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"June"-"Saturday"',
#   '"02:55 pm"',
#   '0',
#   '"Male"',
#   '"022"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2018-"June"-"Friday"',
#   '"05:20 pm"',
#   '0',
#   '"Male"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"June"-"Friday"',
#   '"05:20 pm"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"June"-"Tuesday"',
#   '"04:35 pm"',
#   '0',
#   '"Male"',
#   '"054"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"June"-"Tuesday"',
#   '"04:35 pm"',
#   '0',
#   '"Female"',
#   '"076"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2018-"July"-"Wednesday"',
#   '"05:49 pm"',
# ...
#   '"08:30 am"',
#   '0',
#   '"Male"',
#   '"034"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"March"-"Tuesday"',
#   '"08:30 am"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Friday"',
#   '"01:30 am"',
#   '0',
#   '"Male"',
#   '"020"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"April"-"Friday"', '"01:30 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"April"-"Monday"',
#   '"09:50 am"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Monday"',
#   '"09:50 am"',
#   '0',
#   '"Male"',
#   '"066"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"April"-"Tuesday"',
#   '"01:50 pm"',
#   '0',
#   '"Female"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Tuesday"',
#   '"01:50 pm"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"03:30 pm"',
#   '0',
#   '"Female"',
#   '"004"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"03:30 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Unlicenced"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Tuesday"',
#   '"03:00 pm"',
#   '0',
#   '"Female"',
#   '"072"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"April"-"Tuesday"', '"03:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"April"-"Sunday"',
#   '"05:00 pm"',
#   '0',
#   '"Male"',
#   '"051"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Sunday"',
#   '"05:00 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"05:25 pm"',
#   '0',
#   '"Male"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"05:25 pm"',
#   '0',
#   '"Female"',
#   '"038"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"07:30 pm"',
#   '0',
#   '"Male"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"April"-"Thursday"',
#   '"07:30 pm"',
#   '0',
#   '"Female"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Monday"',
#   '"06:00 pm"',
#   '0',
#   '"Male"',
#   '"047"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Monday"',
#   '"06:00 pm"',
#   '0',
#   '"Male"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Wednesday"',
#   '"03:55 pm"',
#   '1',
#   '"Male"',
#   '"047"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"May"-"Wednesday"',
#   '"03:55 pm"',
#   '0',
#   '"Female"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Thursday"',
#   '"10:30 am"',
#   '0',
#   '"Male"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Thursday"',
#   '"10:30 am"',
#   '0',
#   '"Male"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Wednesday"',
#   '"02:15 pm"',
#   '1',
#   '"Male"',
#   '"066"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Wednesday"',
#   '"02:15 pm"',
#   '0',
#   '"Female"',
#   '"049"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Saturday"',
#   '"04:40 am"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Saturday"',
#   '"04:40 am"',
#   '0',
#   '"Male"',
#   '"068"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Monday"',
#   '"03:05 pm"',
#   '0',
#   '"Male"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"May"-"Monday"',
#   '"03:05 pm"',
#   '0',
#   '"Male"',
#   '"020"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Wednesday"',
#   '"01:20 pm"',
#   '0',
#   '"Female"',
#   '"024"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"June"-"Wednesday"',
#   '"01:20 pm"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Wednesday"',
#   '"11:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"', '2016-"July"-"Wednesday"', '"11:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"July"-"Wednesday"',
#   '"03:17 pm"',
#   '0',
#   '"Male"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Wednesday"',
#   '"03:17 pm"',
#   '0',
#   '"Male"',
#   '"017"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Friday"',
#   '"08:18 am"',
#   '0',
#   '"Male"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Friday"',
#   '"08:18 am"',
#   '0',
#   '"Male"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Monday"',
#   '"05:45 pm"',
#   '1',
#   '"Female"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Monday"',
#   '"05:45 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Monday"',
#   '"05:45 pm"',
#   '0',
#   '"Male"',
#   '"057"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Thursday"',
#   '"08:35 am"',
#   '1',
#   '"Male"',
#   '"051"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"July"-"Thursday"',
#   '"08:35 am"',
#   '0',
#   '"Female"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"July"-"Monday"',
#   '"12:12 am"',
#   '1',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"July"-"Monday"', '"12:12 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"August"-"Thursday"',
#   '"05:50 pm"',
#   '0',
#   '"Male"',
#   '"035"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Thursday"',
#   '"05:50 pm"',
#   '0',
#   '"Male"',
#   '"028"',
#   '"Provisional 1 "'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Wednesday"',
#   '"01:42 pm"',
#   '0',
#   '"Male"',
#   '"075"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Wednesday"',
#   '"01:42 pm"',
#   '1',
#   '"Female"',
#   '"068"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"August"-"Thursday"',
#   '"10:12 pm"',
#   '0',
#   '"Female"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Thursday"',
#   '"10:12 pm"',
#   '0',
#   '"Male"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Sunday"',
#   '"05:00 am"',
#   '1',
#   '"Male"',
#   '"022"',
#   '"Provisional 1 "'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Sunday"',
#   '"05:00 am"',
#   '0',
#   '"Female"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Friday"',
#   '"10:02 am"',
#   '0',
#   '"Female"',
#   '"024"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Friday"',
#   '"10:02 am"',
#   '0',
#   '"Female"',
#   '"034"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Friday"',
#   '"06:45 pm"',
#   '0',
#   '"Female"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Friday"',
#   '"06:45 pm"',
#   '0',
#   '"Female"',
#   '"020"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Monday"',
#   '"02:00 am"',
#   '0',
#   '"Female"',
#   '"022"',
#   '"Full"'),
#  ('"ADELAIDE"', '2016-"August"-"Monday"', '"02:00 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"August"-"Monday"',
#   '"04:00 pm"',
#   '0',
#   '"Female"',
#   '"038"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"August"-"Monday"',
#   '"04:00 pm"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Saturday"',
#   '"01:00 am"',
#   '1',
#   '"Male"',
#   '"024"',
#   '"Disqualified"'),
#  ('"ADELAIDE"', '2016-"September"-"Saturday"', '"01:00 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2016-"September"-"Tuesday"',
#   '"02:00 pm"',
#   '1',
#   '"Female"',
#   '"021"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Tuesday"',
#   '"02:00 pm"',
#   '0',
#   '"Female"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Friday"',
#   '"09:20 am"',
#   '0',
#   '"Male"',
#   '"026"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Friday"',
#   '"09:20 am"',
#   '0',
#   '"Male"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Friday"',
#   '"04:15 pm"',
#   '0',
#   '"Male"',
#   '"032"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Friday"',
#   '"04:15 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Wednesday"',
#   '"12:15 pm"',
#   '0',
#   '"Female"',
#   '"073"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"September"-"Wednesday"',
#   '"12:15 pm"',
#   '1',
#   '"Female"',
#   '"049"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"October"-"Thursday"',
#   '"08:10 pm"',
#   '0',
#   '"Female"',
#   '"023"',
#   '"Unlicenced"'),
#  ('"ADELAIDE"',
#   '2016-"October"-"Thursday"',
#   '"08:10 pm"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"October"-"Saturday"',
#   '"03:30 pm"',
#   '1',
#   '"Female"',
#   '"024"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"October"-"Saturday"',
#   '"03:30 pm"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Thursday"',
#   '"02:45 pm"',
#   '0',
#   '"Male"',
#   '"073"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Thursday"',
#   '"02:45 pm"',
#   '0',
#   '"Female"',
#   '"073"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"08:00 am"',
#   '1',
#   '"Female"',
#   '"039"',
#   ''),
#  ('"ADELAIDE"',
#   '2016-"November"-"Tuesday"',
#   '"08:00 am"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2016-"November"-"Thursday"',
#   '"12:05 pm"',
#   '1',
#   '"Male"',
#   '"070"',
#   ''),
#  ('"ADELAIDE"', '2016-"November"-"Thursday"', '"12:05 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Wednesday"',
#   '"11:18 am"',
#   '0',
#   '"Male"',
#   '"041"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Wednesday"',
#   '"11:18 am"',
#   '0',
#   '"Male"',
#   '"062"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Thursday"',
#   '"04:00 pm"',
#   '1',
#   '"Female"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Thursday"',
#   '"04:00 pm"',
#   '0',
#   '"Male"',
#   '"047"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Thursday"',
#   '"04:00 pm"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"', '2017-"January"-"Thursday"', '"04:00 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"January"-"Saturday"',
#   '"09:21 am"',
#   '1',
#   '"Female"',
#   '"039"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Saturday"',
#   '"09:21 am"',
#   '0',
#   '"Male"',
#   '"018"',
#   '"Probationary"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Tuesday"',
#   '"05:30 pm"',
#   '0',
#   '"Female"',
#   '"033"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"January"-"Tuesday"',
#   '"05:30 pm"',
#   '0',
#   '"Female"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Wednesday"',
#   '"05:10 pm"',
#   '1',
#   '"Male"',
#   '"054"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Wednesday"',
#   '"05:10 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Friday"',
#   '"05:26 pm"',
#   '0',
#   '"Male"',
#   '"057"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Friday"',
#   '"05:26 pm"',
#   '1',
#   '"Male"',
#   '"035"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Sunday"',
#   '"04:54 pm"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Sunday"',
#   '"04:54 pm"',
#   '0',
#   '"Male"',
#   '"054"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Sunday"',
#   '"04:54 pm"',
#   '0',
#   '"Male"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Monday"',
#   '"05:00 pm"',
#   '1',
#   '"Female"',
#   '"041"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"February"-"Monday"',
#   '"05:00 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Tuesday"',
#   '"02:15 pm"',
#   '0',
#   '"Male"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"February"-"Tuesday"',
#   '"02:15 pm"',
#   '1',
#   '"Female"',
#   '"049"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"10:00 am"',
#   '0',
#   '"Male"',
#   '"041"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"10:00 am"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Provisional 1 "'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"01:45 pm"',
#   '1',
#   '"Female"',
#   '"072"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"01:45 pm"',
#   '0',
#   '"Female"',
#   '"077"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Friday"',
#   '"01:05 pm"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Friday"',
#   '"01:05 pm"',
#   '0',
#   '"Male"',
#   '"029"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Friday"',
#   '"01:05 pm"',
#   '1',
#   '"Male"',
#   '"067"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Saturday"',
#   '"12:25 am"',
#   '0',
#   '"Male"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Saturday"',
#   '"12:25 am"',
#   '1',
#   '"Male"',
#   '"033"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"March"-"Saturday"',
#   '"06:30 am"',
#   '0',
#   '"Female"',
#   '"055"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Saturday"',
#   '"06:30 am"',
#   '0',
#   '"Male"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Monday"',
#   '"01:05 pm"',
#   '0',
#   '"Male"',
#   '"061"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Wednesday"',
#   '"07:00 pm"',
#   '0',
#   '"Female"',
#   '"027"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Wednesday"',
#   '"07:00 pm"',
#   '3',
#   '"Male"',
#   '"XXX"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Wednesday"',
#   '"07:00 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Tuesday"',
#   '"05:30 pm"',
#   '0',
#   '"Female"',
#   '"073"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Tuesday"',
#   '"05:30 pm"',
#   '1',
#   '"Male"',
#   '"004"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"03:45 pm"',
#   '0',
#   '"Male"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"March"-"Thursday"',
#   '"03:45 pm"',
#   '0',
#   '"Male"',
#   '"044"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Sunday"',
#   '"03:20 am"',
#   '0',
#   '"Female"',
#   '"019"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Sunday"',
#   '"03:20 am"',
#   '0',
#   '"Male"',
#   '"040"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Monday"',
#   '"05:20 pm"',
#   '0',
#   '"Male"',
#   '"064"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Monday"',
#   '"05:20 pm"',
#   '0',
#   '"Male"',
#   '"035"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Thursday"',
#   '"04:10 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"', '2017-"April"-"Thursday"', '"04:10 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"April"-"Wednesday"',
#   '"06:30 pm"',
#   '0',
#   '"Female"',
#   '"029"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"April"-"Wednesday"',
#   '"06:30 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Friday"',
#   '"09:15 am"',
#   '0',
#   '"Male"',
#   '"035"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"April"-"Friday"',
#   '"09:15 am"',
#   '1',
#   '"Male"',
#   '"047"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"May"-"Wednesday"',
#   '"03:20 pm"',
#   '0',
#   '"Male"',
#   '"063"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Wednesday"',
#   '"03:20 pm"',
#   '0',
#   '"Male"',
#   '"050"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Monday"',
#   '"01:15 pm"',
#   '1',
#   '"Female"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Monday"',
#   '"01:15 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Thursday"',
#   '"10:30 am"',
#   '0',
#   '"Male"',
#   '"088"',
#   '"Full"'),
#  ('"ADELAIDE"', '2017-"May"-"Thursday"', '"10:30 am"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"May"-"Tuesday"',
#   '"07:40 am"',
#   '1',
#   '"Male"',
#   '"045"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Tuesday"',
#   '"07:40 am"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Saturday"',
#   '"11:35 am"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Saturday"',
#   '"11:35 am"',
#   '0',
#   '"Male"',
#   '"XXX"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Sunday"',
#   '"05:20 pm"',
#   '0',
#   '"Female"',
#   '"022"',
#   '"Provisional 2"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Sunday"',
#   '"05:20 pm"',
#   '0',
#   '"Male"',
#   '"031"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Tuesday"',
#   '"05:35 pm"',
#   '0',
#   '"Female"',
#   '"023"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Tuesday"',
#   '"05:35 pm"',
#   '0',
#   '"Male"',
#   '"042"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Wednesday"',
#   '"03:15 pm"',
#   '0',
#   '"Female"',
#   '"029"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"May"-"Wednesday"',
#   '"03:15 pm"',
#   '0',
#   '"Male"',
#   '"058"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Wednesday"',
#   '"08:30 am"',
#   '0',
#   '"Female"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Wednesday"',
#   '"08:30 am"',
#   '0',
#   '"Male"',
#   '"046"',
#   ''),
#  ('"ADELAIDE"',
#   '2017-"June"-"Tuesday"',
#   '"08:10 pm"',
#   '0',
#   '"Male"',
#   '"037"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"June"-"Tuesday"',
#   '"08:10 pm"',
#   '0',
#   '"Female"',
#   '"052"',
#   '"Full"'),
#  ('"ADELAIDE"', '2017-"July"-"Friday"', '"02:45 pm"', '0', '', '', ''),
#  ('"ADELAIDE"',
#   '2017-"July"-"Friday"',
#   '"02:45 pm"',
#   '0',
#   '"Unknown"',
#   '"XXX"',
#   '"Unknown"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Saturday"',
#   '"11:30 pm"',
#   '0',
#   '"Male"',
#   '"046"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"July"-"Saturday"',
#   '"11:30 pm"',
#   '0',
#   '"Male"',
#   '"043"',
#   '"Full"'),
#  ('"ADELAIDE"',
#   '2017-"August"-"Saturday"',
#   '"06:30 pm"',
#   '0',
#   '"Female"',
#   '"021"',
#   '"Unknown"'),
#  ...]

# %%
# 2.
# Joining crash and units df on REPORT_ID
# Extracting Suburb and Total Cas for unlicenced drivers and grouping by suburbs

# %%
# %%time
df_joint = df_units.join(df_crashes, df_crashes.REPORT_ID==df_units.REPORT_ID, how='outer')
df_joint.filter(df_joint['Licence Type']=='Unlicenced')\
.groupBy("Suburb")\
.agg(F.sum("No Of Cas").alias("Total Casualities"))\
.show()
# Out:
# +-------------------+-----------------+
# |             Suburb|Total Casualities|
# +-------------------+-----------------+
# |      FLINDERS PARK|              4.0|
# |       POOGINAGORIC|              1.0|
# |     TEA TREE GULLY|              1.0|
# |            HACKHAM|              3.0|
# |   MEDINDIE GARDENS|              0.0|
# |           WISANGER|              1.0|
# |            CUMMINS|              0.0|
# |       BASKET RANGE|              0.0|
# |MURRAY BRIDGE SOUTH|              0.0|
# |      GILLES PLAINS|              6.0|
# |             HAWKER|              0.0|
# |           BEAUFORT|              1.0|
# |             MAGILL|              4.0|
# |            ECHUNGA|              1.0|
# |            CULTANA|              1.0|
# |        EDWARDSTOWN|              3.0|
# |        RISDON PARK|              1.0|
# |          THORNGATE|              0.0|
# |       ANDREWS FARM|             10.0|
# |       TORRENSVILLE|              3.0|
# +-------------------+-----------------+
# only showing top 20 rows
#
# CPU times: user 5.68 ms, sys: 0 ns, total: 5.68 ms
# Wall time: 1.38 s

# %%
# 2.
# sql statements for the same task

# %%
# %%time
a = spark.sql('''
    SELECT Suburb, sum(`No Of Cas`) as `Total Casualities`
    FROM sql_crashes c join sql_units u 
    ON c.REPORT_ID = u.REPORT_ID
    where `Licence Type` == "Unlicenced"
    Group By Suburb
''')
a.show()
# Out:
# +-------------------+-----------------+
# |             Suburb|Total Casualities|
# +-------------------+-----------------+
# |      FLINDERS PARK|              4.0|
# |       POOGINAGORIC|              1.0|
# |     TEA TREE GULLY|              1.0|
# |            HACKHAM|              3.0|
# |   MEDINDIE GARDENS|              0.0|
# |           WISANGER|              1.0|
# |            CUMMINS|              0.0|
# |       BASKET RANGE|              0.0|
# |MURRAY BRIDGE SOUTH|              0.0|
# |      GILLES PLAINS|              6.0|
# |             HAWKER|              0.0|
# |           BEAUFORT|              1.0|
# |             MAGILL|              4.0|
# |            ECHUNGA|              1.0|
# |            CULTANA|              1.0|
# |        EDWARDSTOWN|              3.0|
# |        RISDON PARK|              1.0|
# |          THORNGATE|              0.0|
# |       ANDREWS FARM|             10.0|
# |       TORRENSVILLE|              3.0|
# +-------------------+-----------------+
# only showing top 20 rows
#
# CPU times: user 2.57 ms, sys: 0 ns, total: 2.57 ms
# Wall time: 1.7 s

# %%
# 2.
# rdd statements for the same task

# %%
# %%time
rdd_joint = rdd_crashes_3.join(rdd_units_3)
rdd_join_1 = rdd_joint.map(lambda x: (x[1][0][1], x[1][1][1], x[1][1][10]))
rdd_join_2 = rdd_join_1.filter(lambda x: x[2] == '"Unlicenced"').map(lambda x: (x[0],int(x[1])))
rdd_join_3 = rdd_join_2.reduceByKey(lambda a,b : a+b) 
rdd_join_3.collect()
# Out:
# CPU times: user 44.7 ms, sys: 0 ns, total: 44.7 ms
# Wall time: 6.47 s
# [('"SOUTH PLYMPTON"', 4),
#  ('"ELIZABETH DOWNS"', 6),
#  ('"MILE END"', 4),
#  ('"PORT LINCOLN"', 2),
#  ('"BOWDEN"', 0),
#  ('"MODBURY"', 2),
#  ('"WINGFIELD"', 3),
#  ('"TORRENSVILLE"', 3),
#  ('"SELLICKS HILL"', 0),
#  ('"MENINGIE"', 2),
#  ('"NORTHFIELD"', 1),
#  ('"BIRKENHEAD"', 2),
#  ('"ROSE PARK"', 0),
#  ('"PORT AUGUSTA WEST"', 2),
#  ('"WHYALLA NORRIE"', 5),
#  ('"GOOLWA BEACH"', 1),
#  ('"GAWLER BELT"', 0),
#  ('"TATACHILLA"', 1),
#  ('"YAMBA"', 1),
#  ('"ELIZABETH GROVE"', 5),
#  ('"SMITHFIELD"', 3),
#  ('"GLENGOWRIE"', 1),
#  ('"HILLIER"', 1),
#  ('"BINNUM"', 1),
#  ('"MARION"', 3),
#  ('"HAWKER"', 0),
#  ('"PARALOWIE"', 2),
#  ('"BRIGHTON"', 2),
#  ('"YALATA"', 1),
#  ('"OAKLANDS PARK"', 1),
#  ('"CURRENCY CREEK"', 5),
#  ('"MEDINDIE GARDENS"', 0),
#  ('"CRYSTAL BROOK"', 0),
#  ('"OLARY"', 0),
#  ('"CUNLIFFE"', 1),
#  ('"BLAKEVIEW"', 3),
#  ('"CHANDLERS HILL"', 1),
#  ('"SEMAPHORE SOUTH"', 3),
#  ('"BOLTO"', 0),
#  ('"SEAFORD RISE"', 0),
#  ('"RENMARK SOUTH"', 1),
#  ('"ANANGU PITJANTJATJARA YANKUNYTJATJARA"', 0),
#  ('"HACKHAM"', 3),
#  ('"ENCOUNTER BAY"', 1),
#  ('"RIVERGLADES"', 0),
#  ('"PORT PIRIE SOUTH"', 1),
#  ('"HUNTFIELD HEIGHTS"', 2),
#  ('"WISANGER"', 1),
#  ('"LOXTON NORTH"', 0),
#  ('"SNOWTOWN"', 1),
#  ('"PURNONG"', 1),
#  ('"ROSEWORTHY"', 5),
#  ('"WATERFALL GULLY"', 0),
#  ('"UNLEY PARK"', 0),
#  ('"RIDGEHAVEN"', 0),
#  ('"FARRELL FLAT"', 0),
#  ('"BIRDWOOD"', 0),
#  ('"BOLIVAR"', 2),
#  ('"MOSQUITO HILL"', 0),
#  ('"NETLEY"', 1),
#  ('"ANANGU PITJANTJATJARA YANKUNYTJATARA"', 2),
#  ('"TELOWIE"', 0),
#  ('"ANDREWS"', 0),
#  ('"MODBURY HEIGHTS"', 1),
#  ('"CROYDON"', 3),
#  ('"MARINO"', 1),
#  ('"KURRALTA PARK"', 1),
#  ('"AMATA"', 1),
#  ('"KENT TOWN"', 0),
#  ('"UNLEY"', 2),
#  ('"WINDSOR GARDENS"', 1),
#  ('"ANGLE VALE"', 4),
#  ('"STIRLING"', 1),
#  ('"NILDOTTIE"', 1),
#  ('"RENMARK"', 0),
#  ('"WOODVILLE WEST"', 2),
#  ('"DULWICH"', 0),
#  ('"SEDDON"', 0),
#  ('"BROADVIEW"', 4),
#  ('"JOSLIN"', 0),
#  ('"FULHAM"', 0),
#  ('"VALE PARK"', 1),
#  ('"CONMURRA"', 1),
#  ('"ALLENBY GARDENS"', 1),
#  ('"BAUDIN BEACH"', 2),
#  ('"BLACKWOOD"', 1),
#  ('"WARNERTOWN"', 1),
#  ('"WALKLEY HEIGHTS"', 0),
#  ('"ANGASTON"', 2),
#  ('"PAYNEHAM"', 3),
#  ('"KANGARILLA"', 3),
#  ('"DERNANCOURT"', 1),
#  ('"LOBETHAL"', 0),
#  ('"ROCKY GULLY"', 1),
#  ('"ASHTON"', 0),
#  ('"HOSKIN CORNER"', 0),
#  ('"LINCOLN NATIONAL PARK"', 0),
#  ('"SEACOMBE HEIGHTS"', 0),
#  ('"CUMMINS"', 0),
#  ('"OAKDEN"', 2),
#  ('"COCKATOO VALLEY"', 0),
#  ('"TRANMERE"', 5),
#  ('"PAYNEHAM SOUTH"', 0),
#  ('"DUDLEY PARK"', 0),
#  ('"LYNTON"', 0),
#  ('"GREENACRES"', 0),
#  ('"COMPTON"', 0),
#  ('"CYGNET RIVER"', 1),
#  ('"NEPABUNNA"', 1),
#  ('"POINT PASS"', 0),
#  ('"WILLASTON"', 0),
#  ('"DARLINGTON"', 1),
#  ('"BARMERA"', 0),
#  ('"MARRYATVILLE"', 1),
#  ('"SHEIDOW PARK"', 0),
#  ('"UNDALYA"', 2),
#  ('"REEVES PLAINS"', 0),
#  ('"LENSWOOD"', 0),
#  ('"YUNTA"', 3),
#  ('"LEAWOOD GARDENS"', 1),
#  ('"PAECHTOWN"', 0),
#  ('"WESTALL"', 1),
#  ('"LITTLEHAMPTON"', 0),
#  ('"PALMER"', 1),
#  ('"COWELL"', 1),
#  ('"FINNISS"', 1),
#  ('"WYNN VALE"', 4),
#  ('"WOODVILLE GARDENS"', 2),
#  ('"BURR WELL"', 0),
#  ('"SALISBURY PLAIN"', 4),
#  ('"TAPEROO"', 1),
#  ('"TAILEM BEND"', 1),
#  ('"BURTON"', 8),
#  ('"GLENSIDE"', 1),
#  ('"NOVAR GARDENS"', 2),
#  ('"O\'HALLORAN HILL"', 2),
#  ('"GAWLER EAST"', 0),
#  ('"TUSMORE"', 0),
#  ('"TANUNDA"', 0),
#  ('"EYRE"', 4),
#  ('"CLARENCE GARDENS"', 0),
#  ('"KINGS PARK"', 0),
#  ('"SALISBURY HEIGHTS"', 1),
#  ('"SEDAN"', 3),
#  ('"COFFIN BAY"', 1),
#  ('"WOODVILLE"', 1),
#  ('"THEBARTON"', 0),
#  ('"NORTH PLYMPTON"', 0),
#  ('"WALKERVILLE"', 1),
#  ('"OLYMPIC DAM"', 1),
#  ('"DIREK"', 3),
#  ('"ROCKY CAMP"', 1),
#  ('"LARGS NORTH"', 1),
#  ('"BEULAH PARK"', 2),
#  ('"KANGAROO INN"', 1),
#  ('"HAWTHORNDENE"', 0),
#  ('"VALLEY VIEW"', 3),
#  ('"MURRAY BRIDGE EAST"', 1),
#  ('"SELLICKS BEACH"', 0),
#  ('"TROTT PARK"', 0),
#  ('"UNDERDALE"', 1),
#  ('"WILD HORSE PLAINS"', 1),
#  ('"NURIOOTPA"', 1),
#  ('"NORTH MOONTA"', 0),
#  ('"UPPER HERMITAGE"', 0),
#  ('"KOONAMORE"', 0),
#  ('"FORESTVILLE"', 1),
#  ('"COLLEGE PARK"', 2),
#  ('"FLAGSTAFF HILL"', 3),
#  ('"KILKENNY"', 0),
#  ('"BRINKLEY"', 0),
#  ('"CALOOTE"', 0),
#  ('"SEFTON PARK"', 0),
#  ('"RISDON PARK"', 1),
#  ('"TRINITY GARDENS"', 0),
#  ('"GOOLWA SOUTH"', 0),
#  ('"NANGKITA"', 0),
#  ('"HASLAM"', 1),
#  ('"SOUTH BRIGHTON"', 0),
#  ('"BROWN HILL CREEK"', 0),
#  ('"STREAKY BAY"', 0),
#  ('"ANNADALE"', 1),
#  ('"REDWOOD PARK"', 2),
#  ('"NANGWARRY"', 1),
#  ('"SUMMERTOWN"', 3),
#  ('"TENNYSON"', 1),
#  ('"WIGLEY FLAT"', 1),
#  ('"CLARENDON"', 0),
#  ('"ROSSLYN PARK"', 1),
#  ('"BRUKUNGA"', 1),
#  ('"SEMAPHORE PARK"', 2),
#  ('"GILLES PLAINS"', 6),
#  ('"VIRGINIA"', 2),
#  ('"PORT WILLUNGA"', 0),
#  ('"LOWER INMAN VALLEY"', 2),
#  ('"ELIZABETH SOUTH"', 5),
#  ('"STURT"', 2),
#  ('"KADINA"', 1),
#  ('"OSBORNE"', 3),
#  ('"WATERLOO CORNER"', 5),
#  ('"MAYLANDS"', 0),
#  ('"PARK HOLME"', 3),
#  ('"SMITHFIELD PLAINS"', 1),
#  ('"ROYSTON PARK"', 0),
#  ('"RICHMOND"', 1),
#  ('"MOUNT GAMBIER"', 7),
#  ('"BEDFORD PARK"', 6),
#  ('"MODBURY NORTH"', 2),
#  ('"COROMANDEL EAST"', 1),
#  ('"FREELING"', 2),
#  ('"MAWSON LAKES"', 5),
#  ('"OTTOWAY"', 1),
#  ('"MOUNT BARKER"', 5),
#  ('"WEST BEACH"', 0),
#  ('"KUDLA"', 0),
#  ('"PARKSIDE"', 1),
#  ('"MARDEN"', 2),
#  ('"MYPONGA"', 4),
#  ('"KALBEEBA"', 0),
#  ('"MORPHETTVILLE"', 2),
#  ('"BUTE"', 0),
#  ('"KORUNYE"', 2),
#  ('"ST AGNES"', 2),
#  ('"ALDINGA"', 2),
#  ('"RENMARK NORTH"', 0),
#  ('"PENRICE"', 1),
#  ('"GREENWITH"', 1),
#  ('"KEPPOCH"', 1),
#  ('"HYDE PARK"', 0),
#  ('"THORNGATE"', 0),
#  ('"ECHUNGA"', 1),
#  ('"FITZROY"', 2),
#  ('"MOUNT TORRENS"', 0),
#  ('"VERDUN"', 1),
#  ('"NORMANVILLE"', 1),
#  ('"ARDROSSAN"', 0),
#  ('"STRUAN"', 0),
#  ('"IWANTJA"', 2),
#  ('"RISDON PARK SOUTH"', 0),
#  ('"BORDERTOWN"', 3),
#  ('"COONDAMBO"', 0),
#  ('"POOGINAGORIC"', 1),
#  ('"CALOMBA"', 0),
#  ('"HAINES"', 2),
#  ('"LYRUP"', 0),
#  ('"GOMERSAL"', 0),
#  ('"BASKET RANGE"', 0),
#  ('"GEORGETOWN"', 2),
#  ('"WALLAROO MINES"', 0),
#  ('"EDWARDSTOWN"', 3),
#  ('"CUDLEE CREEK"', 2),
#  ('"FULHAM GARDENS"', 2),
#  ('"CRAIGMORE"', 2),
#  ('"URRBRAE"', 2),
#  ('"HACKHAM WEST"', 2),
#  ('"BURRA"', 6),
#  ('"REGENCY PARK"', 2),
#  ('"PADTHAWAY"', 0),
#  ('"WOODVILLE SOUTH"', 0),
#  ('"COWANDILLA"', 0),
#  ('"POORAKA"', 1),
#  ('"SEAFORD"', 2),
#  ('"MURRAY BRIDGE"', 6),
#  ('"BELAIR"', 1),
#  ('"WORROLONG"', 0),
#  ('"WEST CROYDON"', 0),
#  ('"WINDSOR"', 1),
#  ('"HALLETT COVE"', 3),
#  ('"LONSDALE"', 4),
#  ('"TRURO"', 0),
#  ('"ELIZABETH"', 2),
#  ('"CHRISTIES BEACH"', 2),
#  ('"SOMERTON PARK"', 1),
#  ('"YORKETOWN"', 2),
#  ('"MOUNT BRYAN"', 2),
#  ('"CLEARVIEW"', 0),
#  ('"HILTON"', 1),
#  ('"DAVOREN PARK"', 6),
#  ('"BRAHMA LODGE"', 1),
#  ('"PENNESHAW"', 1),
#  ('"HECTORVILLE"', 0),
#  ('"ST CLAIR"', 2),
#  ('"CONDOWIE"', 0),
#  ('"MUNNO PARA WEST"', 0),
#  ('"WHYALLA STUART"', 3),
#  ('"MOONTA BAY"', 0),
#  ('"MOUNT MARY"', 1),
#  ('"GLANVILLE"', 0),
#  ('"GOOLWA"', 1),
#  ('"ETTRICK"', 1),
#  ('"MURRAY BRIDGE NORTH"', 1),
#  ('"EVANSTON SOUTH"', 0),
#  ('"HAMLEY BRIDGE"', 1),
#  ('"OAKDEN HILLS"', 1),
#  ('"GLENELG SOUTH"', 1),
#  ('"INNESTON"', 2),
#  ('"YAHL"', 1),
#  ('"ASHFORD"', 0),
#  ('"PENNINGTON"', 1),
#  ('"ALBERT PARK"', 0),
#  ('"INGLEWOOD"', 0),
#  ('"OVERLAND CORNER"', 2),
#  ('"LINWOOD"', 1),
#  ('"HENDON"', 0),
#  ('"WELLAND"', 0),
#  ('"MCDOUALL PEAK"', 1),
#  ('"WILLUNGA"', 1),
#  ('"PORTER LAGOON"', 1),
#  ('"UMUWA"', 0),
#  ('"MCCRACKEN"', 0),
#  ('"BOWER"', 0),
#  ('"BUCKLAND PARK"', 1),
#  ('"TANTANOOLA"', 0),
#  ('"KINGSCOTE"', 0),
#  ('"MALVERN"', 0),
#  ('"PARA HILLS WEST"', 3),
#  ('"GAWLER SOUTH"', 2),
#  ('"PORT ELLIOT"', 1),
#  ('"WARRADALE"', 4),
#  ('"VICTOR HARBOR"', 2),
#  ('"ADELAIDE"', 8),
#  ('"ASHVILLE"', 1),
#  ('"WILLIAMSTOWN"', 1),
#  ('"GLENELG"', 0),
#  ('"MORPHETT VALE"', 6),
#  ('"KERSBROOK"', 1),
#  ('"HINDMARSH VALLEY"', 2),
#  ('"MUNNO PARA DOWNS"', 1),
#  ('"DRY CREEK"', 11),
#  ('"BIBARINGA"', 1),
#  ('"SUTTONTOWN"', 3),
#  ('"ELIZABETH NORTH"', 4),
#  ('"PROSPECT"', 11),
#  ('"KONGORONG"', 1),
#  ('"OLD NOARLUNGA"', 2),
#  ('"ST MARYS"', 3),
#  ('"BERRI"', 1),
#  ('"YATTALUNGA"', 3),
#  ('"HOLDEN HILL"', 6),
#  ('"ALDINGA BEACH"', 2),
#  ('"KAINTON"', 0),
#  ('"POINT STURT"', 1),
#  ('"NARACOORTE"', 2),
#  ('"TOORAK GARDENS"', 0),
#  ('"GOLDEN GROVE"', 2),
#  ('"KENSINGTON GARDENS"', 0),
#  ('"ALLENDALE EAST"', 1),
#  ('"MOORAK"', 0),
#  ('"PEWSEY VALE"', 4),
#  ('"HINDMARSH"', 1),
#  ('"HAMPSTEAD GARDENS"', 0),
#  ('"HOPE VALLEY"', 0),
#  ('"INKERMAN"', 2),
#  ('"MILLSWOOD"', 0),
#  ('"NORTHGATE"', 0),
#  ('"CAVAN"', 1),
#  ('"MILE END SOUTH"', 1),
#  ('"GLOSSOP"', 1),
#  ('"GLANDORE"', 1),
#  ('"AUBURN"', 1),
#  ('"MONARTO"', 0),
#  ('"STIRLING NORTH"', 2),
#  ('"HACKNEY"', 1),
#  ('"WOODVILLE NORTH"', 2),
#  ('"HAWTHORN"', 1),
#  ('"GLADSTONE"', 0),
#  ('"REYNELLA"', 1),
#  ('"HALLETT"', 0),
#  ('"MEADOWS"', 5),
#  ('"WESTBOURNE PARK"', 0),
#  ('"NEWTON"', 1),
#  ('"WALLAROO"', 2),
#  ('"BROWNLOW"', 0),
#  ('"TEA TREE GULLY"', 1),
#  ('"WARD BELT"', 1),
#  ('"SPALDING"', 0),
#  ('"PORT MACDONNELL"', 1),
#  ('"BETHANY"', 1),
#  ('"INGLE FARM"', 5),
#  ('"OVINGHAM"', 1),
#  ('"WAYVILLE"', 1),
#  ('"LOCKLEYS"', 1),
#  ('"FULLARTON"', 0),
#  ('"WEST LAKES"', 1),
#  ('"SALISBURY EAST"', 8),
#  ('"NORTH ADELAIDE"', 7),
#  ('"MCLAREN FLAT"', 0),
#  ('"MILLICENT"', 2),
#  ('"SEATON"', 4),
#  ('"WILMINGTON"', 3),
#  ('"PENONG"', 1),
#  ('"WEST RICHMOND"', 1),
#  ('"CHAFFEY"', 1),
#  ('"ALBERTON"', 1),
#  ('"DOUGLAS POINT"', 1),
#  ('"ROSTREVOR"', 1),
#  ('"SALISBURY SOUTH"', 0),
#  ('"FIRLE"', 0),
#  ('"CASSINI"', 1),
#  ('"MILLBROOK"', 1),
#  ('"MOUNT GEORGE"', 1),
#  ('"NORTH BRIGHTON"', 0),
#  ('"HILLBANK"', 1),
#  ('"HENLEY BEACH SOUTH"', 2),
#  ('"ONE TREE HILL"', 2),
#  ('"TODMORDEN"', 1),
#  ('"POLTALLOCH"', 1),
#  ('"GLENELG EAST"', 0),
#  ('"SEPPELTSFIELD"', 0),
#  ('"SEAFORD MEADOWS"', 2),
#  ('"SEMAPHORE"', 0),
#  ('"KAPUNDA"', 3),
#  ('"LAMEROO"', 2),
#  ('"LINDEN PARK"', 0),
#  ('"FAIRVIEW PARK"', 0),
#  ('"CRAFERS WEST"', 0),
#  ('"GLENUNGA"', 0),
#  ('"FELIXSTOW"', 2),
#  ('"MELROSE PARK"', 2),
#  ('"LOWER MITCHAM"', 0),
#  ('"GLEN OSMOND"', 1),
#  ('"CLAY WELLS"', 1),
#  ('"ATHELSTONE"', 0),
#  ('"NEW PORT"', 0),
#  ('"MYRTLE BANK"', 0),
#  ('"STOCKPORT"', 1),
#  ('"WHYALLA JENKINS"', 1),
#  ('"WAIKERIE"', 1),
#  ('"HAZELWOOD PARK"', 1),
#  ('"BLYTH"', 1),
#  ('"HAHNDORF"', 2),
#  ('"NALYAPPA"', 1),
#  ('"PIKE RIVER"', 0),
#  ('"PORT PIRIE WEST"', 0),
#  ('"APY"', 3),
#  ('"DAW PARK"', 0),
#  ('"MURRAY BRIDGE SOUTH"', 0),
#  ('"MANNANARIE"', 2),
#  ('"CRAFERS"', 1),
#  ('"HALBURY"', 1),
#  ('"HORSNELL GULLY"', 0),
#  ('"WALKER FLAT"', 1),
#  ('"MONTEITH"', 0),
#  ('"MCHARG CREEK"', 2),
#  ('"CROYDON PARK"', 0),
#  ('"SALISBURY DOWNS"', 8),
#  ('"ENFIELD"', 11),
#  ('"KLEMZIG"', 1),
#  ('"ELIZABETH VALE"', 3),
#  ('"MITCHELL PARK"', 1),
#  ('"TWO WELLS"', 2),
#  ('"ELIZABETH EAST"', 3),
#  ('"LOWER LIGHT"', 1),
#  ('"CULTANA"', 1),
#  ('"KENSINGTON"', 0),
#  ('"GAWLER"', 0),
#  ('"BLAIR ATHOL"', 1),
#  ('"PORT AUGUSTA"', 2),
#  ('"CALLINGTON"', 2),
#  ('"ASCOT PARK"', 2),
#  ('"PLYMPTON"', 4),
#  ('"LOXTON"', 0),
#  ('"ANNA CREEK"', 0),
#  ('"MOUNT CRAWFORD"', 1),
#  ('"CHRISTIE DOWNS"', 5),
#  ('"CEDUNA"', 2),
#  ('"KINGSTON ON MURRAY"', 1),
#  ('"BEAUFORT"', 1),
#  ('"PINNAROO"', 2),
#  ('"WHYALLA PLAYFORD"', 3),
#  ('"IRONBANK"', 0),
#  ('"ERINGA"', 1),
#  ('"ST PETERS"', 1),
#  ('"COOBER PEDY"', 7),
#  ('"WEST HINDMARSH"', 2),
#  ('"MCLAREN VALE"', 3),
#  ('"KIDMAN PARK"', 0),
#  ('"CHELTENHAM"', 1),
#  ('"KENSINGTON PARK"', 0),
#  ('"HIGHGATE"', 0),
#  ('"PANORAMA"', 0),
#  ('"COLLINSWOOD"', 2),
#  ('"OLD REYNELLA"', 0),
#  ('"MONARTO SOUTH"', 2),
#  ('"PARA HILLS"', 4),
#  ('"GLYNDE"', 1),
#  ('"JAMESTOWN"', 1),
#  ('"BROMPTON"', 1),
#  ('"CAMDEN PARK"', 1),
#  ('"HOUGHTON"', 2),
#  ('"MIDDLEBACK RANGE"', 1),
#  ('"PARAFIELD"', 0),
#  ('"FREWVILLE"', 0),
#  ('"PARIS CREEK"', 1),
#  ('"CARAWA"', 2),
#  ('"CAREY GULLY"', 1),
#  ('"PARA VISTA"', 2),
#  ('"YANKALILLA"', 0),
#  ('"MONBULLA"', 0),
#  ('"MALLALA"', 1),
#  ('"SEACLIFF"', 0),
#  ('"ST MORRIS"', 0),
#  ('"WINNINOWIE"', 0),
#  ('"LANGHORNE CREEK"', 1),
#  ('"KULPARA"', 1),
#  ('"PORT RICKABY"', 1),
#  ('"PARILLA"', 0),
#  ('"JERICHO"', 0),
#  ('"MOUNT COMPASS"', 1),
#  ('"FIELD"', 1),
#  ('"MANNINGHAM"', 0),
#  ('"NOARLUNGA CENTRE"', 1),
#  ('"ATHOL PARK"', 1),
#  ('"PARAFIELD GARDENS"', 5),
#  ('"SALISBURY"', 11),
#  ('"BOOKABIE"', 1),
#  ('"MANSFIELD PARK"', 0),
#  ('"ROYAL PARK"', 1),
#  ('"NOARLUNGA DOWNS"', 1),
#  ('"ELIZABETH PARK"', 8),
#  ('"PORT ADELAIDE"', 2),
#  ('"PENFIELD GARDENS"', 2),
#  ('"SURREY DOWNS"', 0),
#  ('"RENOWN PARK"', 1),
#  ('"FINDON"', 1),
#  ('"ROXBY DOWNS"', 2),
#  ('"VISTA"', 0),
#  ('"HENLEY BEACH"', 1),
#  ('"BORRIKA"', 0),
#  ('"WOODVILLE PARK"', 1),
#  ('"HAPPY VALLEY"', 3),
#  ('"COLONEL LIGHT GARDENS"', 0),
#  ('"WILLAMULKA"', 1),
#  ('"FERRYDEN PARK"', 2),
#  ('"KILBURN"', 2),
#  ('"MASLIN BEACH"', 1),
#  ('"PASADENA"', 2),
#  ('"ANDREWS FARM"', 10),
#  ('"SOLOMONTOWN"', 0),
#  ('"CRESCENT"', 1),
#  ('"ULEYBURY"', 0),
#  ('"YATALA VALE"', 1),
#  ('"MERRITON"', 0),
#  ('"MAITLAND"', 0),
#  ('"BRIDGEWATER"', 2),
#  ('"STEPNEY"', 2),
#  ('"SALISBURY PARK"', 0),
#  ('"BALHANNAH"', 2),
#  ('"PARACOMBE"', 3),
#  ('"PUKATJA"', 3),
#  ('"LOUTH BAY"', 1),
#  ('"MINGBOOL"', 1),
#  ('"MEDINDIE"', 1),
#  ('"EVANSTON PARK"', 3),
#  ('"O\'SULLIVAN BEACH"', 2),
#  ('"SOUTHEND"', 1),
#  ('"PENFIELD"', 4),
#  ('"PORT NOARLUNGA SOUTH"', 1),
#  ('"COMMISSARIAT POINT"', 1),
#  ('"HARTLEY"', 1),
#  ('"GULFVIEW HEIGHTS"', 0),
#  ('"WHYALLA"', 1),
#  ('"ALMA"', 0),
#  ('"GAWLER WEST"', 2),
#  ('"NAIRNE"', 0),
#  ('"LARGS BAY"', 2),
#  ('"PIPALYATJARA"', 0),
#  ('"ABERFOYLE PARK"', 0),
#  ('"GOULD CREEK"', 0),
#  ('"CLARENCE PARK"', 0),
#  ('"NORTON SUMMIT"', 0),
#  ('"EDINBURGH"', 2),
#  ('"SAMPSON FLAT"', 1),
#  ('"GREENHILL"', 0),
#  ('"TUNGKILLO"', 0),
#  ('"ST GEORGES"', 1),
#  ('"LEABROOK"', 0),
#  ('"FLINDERS PARK"', 4),
#  ('"LOCHABER"', 1),
#  ('"GEPPS CROSS"', 1),
#  ('"SALISBURY NORTH"', 7),
#  ('"CAMPBELLTOWN"', 2),
#  ('"RIDLEYTON"', 2),
#  ('"MUNNO PARA"', 5),
#  ('"QUEENSTOWN"', 0),
#  ('"PORT NOARLUNGA"', 2),
#  ('"PORT WAKEFIELD"', 0),
#  ('"ROSEWATER"', 0),
#  ('"BEVERLEY"', 1),
#  ('"BROOKLYN PARK"', 4),
#  ('"MAGILL"', 4),
#  ('"CLOVELLY PARK"', 1),
#  ('"CLELAND"', 0),
#  ('"KESWICK"', 1),
#  ('"FORRESTON"', 1),
#  ('"TORRENS PARK"', 2),
#  ('"NORWOOD"', 3),
#  ('"ONKAPARINGA HILLS"', 5),
#  ('"GLOBE DERBY PARK"', 1),
#  ('"TOOPERANG"', 1),
#  ('"DAWESLEY"', 3),
#  ('"KESWICK TERMINAL"', 0),
#  ('"CHAIN OF PONDS"', 2),
#  ('"GRANGE"', 0),
#  ('"EVERARD PARK"', 1),
#  ('"PARADISE"', 2),
#  ('"HOVE"', 1),
#  ('"TOTHILL CREEK"', 1),
#  ('"TUMBY BAY"', 0),
#  ('"TOTNESS"', 2),
#  ('"HIGHBURY"', 1),
#  ('"GLENELG NORTH"', 4),
#  ('"SWAN REACH"', 2),
#  ('"NAILSWORTH"', 0),
#  ('"BEACHPORT"', 1),
#  ('"ARMAGH"', 1),
#  ('"TINTINARA"', 0),
#  ('"HILLCREST"', 0),
#  ('"CUMBERLAND PARK"', 0),
#  ('"EDINBURGH NORTH"', 1),
#  ('"ETHELTON"', 1),
#  ('"FITZGERALD BAY"', 1),
#  ('"EVANSTON"', 1),
#  ('"THE PINES"', 1),
#  ('"TIATUKIA"', 2),
#  ('"SEACLIFF PARK"', 0),
#  ('"CLARE"', 0),
#  ('"WHITES FLAT"', 0),
#  ('"GREEN FIELDS"', 1),
#  ('"LIGHTSVIEW"', 0),
#  ('"ANGLE PARK"', 0),
#  ('"PORT PIRIE"', 0),
#  ('"EIGHT MILE CREEK"', 1),
#  ('"HEATHPOOL"', 0)]

# %% [markdown]
# After looking at the time statistics we can conclude that the sql query performs the best while the rdd commands work the slowest for the given tasks/\.
